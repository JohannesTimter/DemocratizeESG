# %%
from Gemini import generatePromptsDictionary
import io
from Fullcontext_main import retrieveCompanyYearReports
from google import genai
client = genai.Client()

companyYearReports = retrieveCompanyYearReports("Airlines", "QuantasAirways", "2024")

for doc in companyYearReports:
    print(f"Now prompting document: {doc.company_name} {doc.period} {doc.topic} {doc.mimetype} {doc.counter} ")

    doc_io = io.BytesIO(doc.file_value)
    uploaded_doc =  client.files.upload(
        file=doc_io,
        config=dict(
            mime_type=doc.mimetype)
    )
    print(f"Uploaded doc: {uploaded_doc.name} with MIME type: {uploaded_doc.mime_type}")

    prompts = generatePromptsDictionary(doc)
# Out:
# Download 100 of 2024.pdf application/pdf
# Download 100 of 2024.pdf application/pdf
# Now prompting document: QuantasAirways 2024 Topic.ESG application/pdf 1
# Uploaded doc: files/kj51bhabvcw6 with MIME type: application/pdf
# Now prompting document: QuantasAirways 2024 Topic.FINANCIAL application/pdf 1
# Uploaded doc: files/a2ewqgthk9i4 with MIME type: application/pdf

# %%
from Gemini import IndicatorExtraction

inline_requests = []

for indicatorID in prompts:
    inline_request = {
        "contents": [{
            "parts": [
                {"text": prompts[indicatorID]},
                {"file_data": {"file_uri": uploaded_doc.uri, "mime_type": uploaded_doc.mime_type}}
            ]
        }],
        "config": {
            "thinking_config": {
                  "include_thoughts": True,
            },
            "response_mime_type": "application/json",
            "response_schema": IndicatorExtraction
        }
    }
    inline_requests.append(inline_request)

print(inline_requests)
# Out:
# [{'contents': [{'parts': [{'text': '"Extract the following metric from the provided document:\n      -Money (OpEx, CapEx) used for environmental purposes (EU Taxonomy aligned CapEx and OpEx starting in 2024) of the reporting company QuantasAirways for the year 2024.\n      \n      Metric-specific instructions:\n      OpEx, CapEx used for environmental purposes (Taxonomy aligned). Specifically NOT money invested in carbon credits and offsets, those are already covered in the carbon_credits_offsets indicator. This value may also be specified as total expenses for environmental purposes.\n      From the year 2024 on, you can expect report to include figures of invested CapEx and OpEx that are aligned with climate friendly target according to the EU taxonomy. Prior to this year, general figures for investment in environment causes are sufficient. You should look for tables describing the Operational Expenditure and the Capital Expanditure in the requested period. Find the taxonomy-eligeble and taxonomy-aligned acitivites. You may have to add up the taxonomy-eligeble and taxonomy-aligned OpEx and the taxonomy-eligeble and taxonomy-aligned CapEx. You may have to add up environmental investments and environmental expenses to calculcate the total amount of money spent on environmental purposes.\n      \n      Suggested searchwords (you should still come up with your own searchwords):\n      Environmental Accounting for Fiscal 2022, Investments and operating costs – Environment (2018 – 2022), GM, 2022, Total , The total environmental and decommissioning provision comprises:, ?, A. Eligible activities in accordance with the taxonomy A.1. Environmentally sustainable activities (that align with the taxonomy), Environmental investments and expenses, Environmental protection input, Funds invested in environmental protection, Qantas Climate Fund committed, Total cash capital expenditures for 2023 Environmental\n      \n      General instructions:\n      -Use the provided document as a source of metrics\n      -Only consider english text\n      -You are not an expert at interpreting figures. You are much better at reading tables and text. Knowing this, you prefer reading information from tables and text over using figures, if possible.\n      -Hint: Look for tables in the Appendix and Annexes section of the reports, which can often be found in the last chapter of the documents. Look for tables in sections such as GRI indicatos, SASB Indicators, TCFD Indicators. These tables contain reliable and easy to digest information.\n      -Prefer values in metric tons over values the american short tons\n      -Prefer values in liters over values in gallons\n      -If there are values for the reporting company itself and for the reporting companies group available, use the values of the companies group.\n\n      Response Requirements:\n      -You are only allowed to return a single json object in your response, you can never return multiple results.\n      -Regarding the "is_disclosed" key: If the Information we are looking for is not disclosed in the document, set the is_disclosed field to 0.\n      -Regarding the "page_number" key: Provide the page number, where the respective information was found. \n      -Regarding the "section" key: Provide the text section where you found the information.\n      -The required output format is JSON.\n      \n      Example Output:\n      {            \n            "is_disclosed": 1, \n            "indicator_id": "environmental_ex":,\n            "value": "1.695",\n            "unit": "SEK Millions",\n            "page_number": "92",\n            "section" : "Capital expenditure of environmentally sustainable activities (Taxonomy-aligned) \n(A.1) 832  Operational expenditure of environmentally sustainable activities (Taxonomy\naligned) (A.1) 863"\n      }'}, {'file_data': {'file_uri': 'https://generativelanguage.googleapis.com/v1beta/files/a2ewqgthk9i4', 'mime_type': 'application/pdf'}}]}], 'config': {'thinking_con ...

# %%
inline_batch_job = client.batches.create(
    model="models/gemini-2.5-flash",
    src=inline_requests,
    config={
        'display_name': "quantas-airlines-inline-batch-test1"
    },
)

# %%
# Use the name of the job you want to check
# e.g., inline_batch_job.name from the previous step
job_name0 = "batches/68ohlbuc7numz7ketcvkwizg4dh8povs8eoa"  # (e.g. 'batches/your-batch-id')
job_name = "batches/zi9hlczk1uwzljrevytef2qwqw41djv4wfnq"  # (e.g. 'batches/your-batch-id')
batch_job_from_file = client.batches.get(name=job_name)

import time

completed_states = set([
    'JOB_STATE_SUCCEEDED',
    'JOB_STATE_FAILED',
    'JOB_STATE_CANCELLED',
    'JOB_STATE_EXPIRED',
])

while batch_job_from_file.state.name not in completed_states:
  print(f"Current state: {batch_job_from_file.state.name}")
  time.sleep(30) # Wait for 30 seconds before polling again

print(f"Job finished with state: {batch_job_from_file.state.name}")
if batch_job_from_file.state.name == 'JOB_STATE_FAILED':
    print(f"Error: {batch_job_from_file.error}")
# Out:
# Job finished with state: JOB_STATE_SUCCEEDED

# %%
completed_states = set([
    'JOB_STATE_SUCCEEDED',
    'JOB_STATE_FAILED',
    'JOB_STATE_CANCELLED',
    'JOB_STATE_EXPIRED',
])

print("Listing recent batch jobs:\n")

# Note: The list API currently doesn't return inlined_responses.
# As a workaround,you can make a `get` call for inline jobs to see their results.
batches = client.batches.list(config={'page_size': 10})

for b in batches.page:
    print(f"Job Name: {b.name}")
    print(f"  - Display Name: {b.display_name}")
    print(f"  - State: {b.state.name}")
    print(f"  - Create Time: {b.create_time.strftime('%Y-%m-%d %H:%M:%S')}")
    if b.state.name in completed_states:
        print(f"  - End Time: {b.end_time.strftime('%Y-%m-%d %H:%M:%S')}")




    # Check if it was an inline job (no destination file)
    if b.dest is not None:
      if not b.dest.file_name:
        full_job = client.batches.get(name=b.name)
        if full_job.inlined_responses:
            print("  - Type: Inline ({} responses)".format(len(full_job.inlined_responses)))
      else:
          print(f"  - Type: File-based (Output: {b.dest.file_name})")

    print("-" * 20)
# Out:
# Listing recent batch jobs:
#
# Job Name: batches/5dfzbzpknv9dkwjdy3sx1w9g21u409g92aoj
#   - Display Name: my-batch-job-with-file-and-thoughts-thinking_config
#   - State: JOB_STATE_SUCCEEDED
#   - Create Time: 2025-09-12 16:59:15
#   - End Time: 2025-09-12 17:00:40
#   - Type: File-based (Output: files/batch-5dfzbzpknv9dkwjdy3sx1w9g21u409g92aoj)
# --------------------
# Job Name: batches/nm1ycsfts46b6vh2090bh4xyo9plyvs0dr06
#   - Display Name: quantas-airlines-inline-batch-test1
#   - State: JOB_STATE_SUCCEEDED
#   - Create Time: 2025-09-12 16:51:34
#   - End Time: 2025-09-12 17:00:44
# --------------------
# Job Name: batches/ff0deax8tnaay5rr0gqkn6g22pl3pd4orcrk
#   - Display Name: extraction_attempt_3
#   - State: JOB_STATE_SUCCEEDED
#   - Create Time: 2025-09-11 22:12:59
#   - End Time: 2025-09-12 10:09:13
#   - Type: File-based (Output: files/batch-ff0deax8tnaay5rr0gqkn6g22pl3pd4orcrk)
# --------------------
# Job Name: batches/vnb8p71ws0ug2mgdkb6vmo11xlxspy40okyd
#   - Display Name: my-batch-job-with-file-and-thoughts-thinking_config
#   - State: JOB_STATE_SUCCEEDED
#   - Create Time: 2025-09-11 16:44:56
#   - End Time: 2025-09-11 17:48:30
#   - Type: File-based (Output: files/batch-vnb8p71ws0ug2mgdkb6vmo11xlxspy40okyd)
# --------------------
# Job Name: batches/f9twk9y9jhwrgfyjrpq9h3ucnqr5cypgorio
#   - Display Name: my-batch-job-with-file-and-thoughts
#   - State: JOB_STATE_SUCCEEDED
#   - Create Time: 2025-09-11 00:14:25
#   - End Time: 2025-09-11 03:29:17
#   - Type: File-based (Output: files/batch-f9twk9y9jhwrgfyjrpq9h3ucnqr5cypgorio)
# --------------------
# Job Name: batches/zi9hlczk1uwzljrevytef2qwqw41djv4wfnq
#   - Display Name: my-batch-job-with-file
#   - State: JOB_STATE_SUCCEEDED
#   - Create Time: 2025-09-10 23:57:10
#   - End Time: 2025-09-11 03:16:01
#   - Type: File-based (Output: files/batch-zi9hlczk1uwzljrevytef2qwqw41djv4wfnq)
# --------------------
# Job Name: batches/68ohlbuc7numz7ketcvkwizg4dh8povs8eoa
#   - Display Name: my-batch-job-with-image
#   - State: JOB_STATE_SUCCEEDED
#   - Create Time: 2025-09-10 22:46:36
#   - End Time: 2025-09-11 03:12:10
#   - Type: File-based (Output: files/batch-68ohlbuc7numz7ketcvkwizg4dh8povs8eoa)
# --------------------
# Job Name: batches/juotfcgfm48su8533h4mri00hhvn2vsr8zzz
#   - Display Name: file-upload-job-1
#   - State: JOB_STATE_SUCCEEDED
#   - Create Time: 2025-09-10 19:51:39
#   - End Time: 2025-09-11 03:19:59
#   - Type: File-based (Output: files/batch-juotfcgfm48su8533h4mri00hhvn2vsr8zzz)
# --------------------
# Job Name: batches/hlhhsbjwf7e2i2bx1jqjijoiw8qnpie2g4g2
#   - Display Name: file-upload-job-1
#   - State: BATCH_STATE_EXPIRED
#   - Create Time: 2025-09-03 12:19:31
# --------------------

# %%
batch_job_inline = client.batches.get(name="batches/nm1ycsfts46b6vh2090bh4xyo9plyvs0dr06")

# print the response
for i, inline_response in enumerate(batch_job_inline.dest.inlined_responses, start=1):
    print(f"\n--- Response {i} ---")

    # Check for a successful response
    if inline_response.response:
        # The .text property is a shortcut to the generated text.
        #print(inline_response.response.text)
        print(inline_response.response)
# Out:
# --- Response 1 ---
# sdk_http_response=None candidates=[Candidate(
#   citation_metadata=CitationMetadata(
#     citations=[
#       Citation(
#         end_index=2994,
#         license='',
#         start_index=2625,
#         uri='https://www.listcorp.com/asx/qan/qantas-airways-limited/news/qantas-group-fy22-appendix-4e-and-preliminary-final-report-2752657.html'
#       ),
#     ]
#   ),
#   content=Content(
#     parts=[
#       Part(
#         text="""**Assessing Environmental Expenditure in the Qantas Annual Report for 2024**
#
# Okay, I'm tasked with pinpointing the specific amount of Operational Expenditure (OpEx) and Capital Expenditure (CapEx) Qantas allocated to environmental purposes in 2024, focusing on EU Taxonomy alignment. This is a bit tricky, and I need to be precise.  The goal is clear: identify *only* money spent on environmental initiatives that align with the EU Taxonomy, explicitly excluding any investment in carbon credits and offsets.
#
# My initial search focused on terms like "environmental purposes," "OpEx environmental," "CapEx environmental," "EU Taxonomy aligned," and various related phrases. I immediately turned to the "GROUP SCORECARD OUTCOME 2023/24" on page 41, figuring it would be a likely source.  The "Climate" section caught my eye, particularly the mention of "$4.3 million" for "B2B Offsets and SAF programs." However, the instructions were crystal clear: exclude anything related to carbon credits. This $4.3 million figure is a combined amount for both offsets and Sustainable Aviation Fuel (SAF).  Without a breakdown, I can't confidently isolate the SAF portion, which *would* be considered environmental expenditure. I have to discard this figure, unfortunately, as it's not specific enough.
#
# Next, I looked for other hints. Page 24, discussing climate change, mentioned investments in "modern aircraft technology" and supporting the SAF industry. Page 75 mentioned "capital expenditure to introduce more fuel-efficient aircraft," which *could* be relevant. However, these discussions didn't give me specific financial figures directly related to 2024 that I could use.
#
# I considered combining figures, as the instructions suggested, but the report doesn't seem to break down OpEx and CapEx into specific environmental categories. I found general figures for net capital expenditure ($3,148 million), but this is the total, not just the environmentally focused portion. Page 16 mentions "higher SAF and carbon-offsetting program expenses," again without separating them for 2024.
#
# The challenge is finding data that meets *all* the requirements:  (1) It needs to be OpEx or CapEx; (2) it must be for environmental purposes; (3) it must be related to 2024; (4) it must be EU Taxonomy aligned (or similar); and (5) it *must* exclude carbon credits and offsets. While the report touches on these topics, it doesn't provide the level of detail needed to extract an exact figure that meets all criteria.  The Qantas report seems to emphasize the intent of these environmental activities, but not specific costs.
# """,
#         thought=True
#       ),
#       Part(
#         text="""{
#   "isDisclosed": 0,
#   "indicator_id": "money_environmental_opex_capex",
#   "value": "",
#   "unit": "",
#   "page_number": "",
#   "section": ""
# }"""
#       ),
#     ],
#     role='model'
#   ),
#   finish_reason=<FinishReason.STOP: 'STOP'>,
#   index=0
# )] create_time=None model_version='gemini-2.5-flash' prompt_feedback=None response_id='s1HEaPeuKv-11MkPi7uK8AQ' usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=57,
#   prompt_token_count=37965,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=813
#     ),
#     ModalityTokenCount(
#       modality=<MediaModality.DOCUMENT: 'DOCUMENT'>,
#       token_count=37152
#     ),
#   ],
#   thoughts_token_count=1412,
#   total_token_count=39434
# ) automatic_function_calling_history=None parsed=None
#
# --- Response 2 ---
# sdk_http_response=None candidates=[Candidate(
#   citation_metadata=CitationMetadata(
#     citations=[
#       Citation(
#         end_index=2244,
#         license='',
#         start_index=2034,
#         uri='https://www.listcorp.com/asx/qan/qantas-airways-limited/news/qantas-group-hy24-appendix-4d-and-interim-financial-report-2996874.html'
#       ),
#       Citation(
#         end_index=2608,
#         license='',
#         start_index=2378,
#         uri='https://www.listcorp.com/asx/qan/qantas-airways-limited/news/qantas-group-hy24-appendix-4d-and-interim-financial-report-2996874.html'
#       ),
#       Citation(
#         end_index=6285,
#         license='',
#         start_index=5910,
#         uri='https://www.listcorp.com/asx/qan/qantas-airways-limited/news/qantas-group-fy22-appendix-4e-and-preliminary-final-report-2752657.html'
#       ),
#     ]
#   ),
#   content=Content(
#     parts=[
#       Part(
#         text="""**Assessment of Low-Carbon Revenue for Qantas Airways in 2024**
#
# My analysis focused on identifying "Total revenue from products/services designed for low-carbon economy" for Qantas Airways in the year 2024.  I scrutinized the Annual Report for key phrases like "low-carbon revenue," "taxonomy aligned turnover," and "revenue from products that enable sustainability."
#
# My search led me to the "Group Scorecard Outcome 2023/24" (page 41) and specifically page 42, which details "Performance Assessment of 2023/24 Group Scorecard Measures". It mentions the "SAF Corporate Coalition" and its revenue of $3.3 million. However, after careful consideration of the instructions, particularly the emphasis on revenue generated *by the reporting company itself*, I'm hesitant to directly attribute this $3.3 million as Qantas's own revenue.
#
# The wording "The SAF Corporate Coalition achieved revenue of $3.3 million" suggests it's the total revenue of the coalition, not necessarily Qantas's specific share or revenue directly generated from its low-carbon focused products/services. Qantas is likely a *member* of this coalition, but the report doesn't explicitly state the revenue *to* Qantas from these activities.
#
# The report highlights Qantas's commitment to sustainability and climate action, with detailed information on initiatives like SAF and offsets. However, despite mentions of the SAF Corporate Coalition achieving revenue, no clear figure represents Qantas's standalone revenue from low-carbon products/services.  Therefore, I cannot confidently report a value, and the metric is considered *not disclosed* according to the instruction "Be careful to only consider revenue that was generated by the reporting company itself".
# """,
#         thought=True
#       ),
#       Part(
#         text="""{
#   "isDisclosed": 0,
#   "indicator_id": "lowCarbon_revenue",
#   "value": "",
#   "unit": "",
#   "page_number": "",
#   "section": ""
# }"""
#       ),
#     ],
#     role='model'
#   ),
#   finish_reason=<FinishReason.STOP: 'STOP'>,
#   index=0
# )] create_time=None model_version='gemini-2.5-flash' prompt_feedback=None response_id='t1HEaKiFLrWB1MkP3oSX4A8' usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=52,
#   prompt_token_count=37710,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=558
#     ),
#     ModalityTokenCount(
#       modality=<MediaModality.DOCUMENT: 'DOCUMENT'>,
#       token_count=37152
#     ),
#   ],
#   thoughts_token_count=2818,
#   total_token_count=40580
# ) automatic_function_calling_history=None parsed=None
#
# --- Response 3 ---
# sdk_http_response=None candidates=[Candidate(
#   content=Content(
#     parts=[
#       Part(
#         text="""**Finding Qantas Airways' 2024 Revenue**
#
# Alright, let's see. The user needs the revenue for Qantas Airways for 2024.  I need to find a table or section that clearly lays out that specific data.  I'm looking for terms like "Revenue and other income," "Net turnover," or just "revenue."  Since this is a financial question, I'll naturally head towards the "Financial Report," "Financial and Operational Highlights," or a "Five-Year History" section if they have one.
#
# Looking at the table of contents, I see "Financial Report" starts on page 65, "Five-Year History" is on page 5, and the "Financial and Operational Highlights" are on page 2. I'll start with the "Five-Year History" since it's most likely to be a concise overview.
#
# Page 5 has a table titled "FINANCIAL PERFORMANCE1" - bingo!  There's a row for "Revenue and other income" with columns for the years.  And there it is, under 2024: $M 21,939. That looks promising.  "$M" means millions of Australian Dollars, which is correct given the company.
#
# To be extra sure, let me verify in the "Financial Report." Page 68 has the "Consolidated Income Statement," and there's a section "REVENUE AND OTHER INCOME."  Checking, yep, "Revenue and other income" for 2024 is the same: 21,939 $M. Spot on.
#
# Just to be thorough, I'll peek at page 79, section "4 REVENUE AND OTHER INCOME".  I find again, in section (A) REVENUE AND OTHER INCOME BY GEOGRAPHIC AREA: Total revenue and other income for 2024 is 21,939 $M. So, "Revenue and other income" seems to be the most encompassing metric that matches what's requested.
#
# So, here's my answer:
#
# *   **Value:** 21,939
# *   **Unit:** AUD millions (implicitly)
# *   **Page:** 68
# *   **Section:** Consolidated Income Statement, REVENUE AND OTHER INCOME
# *   **Indicator ID:** revenue
# """,
#         thought=True
#       ),
#       Part(
#         text="""{
#   "isDisclosed": 1,
#   "indicator_id": "revenue",
#   "value": "21,939",
#   "unit": "AUD millions",
#   "page_number": "68",
#   "section": "Consolidated Income Statement, REVENUE AND OTHER INCOME"
# }"""
#       ),
#     ],
#     role='model'
#   ),
#   finish_reason=<FinishReason.STOP: 'STOP'>,
#   index=0
# )] create_time=None model_version='gemini-2.5-flash' prompt_feedback=None response_id='sFHEaOf6ErqB1MkPrsSaSA' usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=73,
#   prompt_token_count=37657,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=505
#     ),
#     ModalityTokenCount(
#       modality=<MediaModality.DOCUMENT: 'DOCUMENT'>,
#       token_count=37152
#     ),
#   ],
#   thoughts_token_count=573,
#   total_token_count=38303
# ) automatic_function_calling_history=None parsed=None
#
# --- Response 4 ---
# sdk_http_response=None candidates=[Candidate(
#   content=Content(
#     parts=[
#       Part(
#         text="""**Analyzing Qantas Airways' 2024 Net Income After Taxes**
#
# Okay, so I've been tasked with finding Qantas Airways' "Profit for the reporting Period," specifically the net income after taxes, for the year 2024. The metric we're looking for is defined as "Statutory Profit/(Loss) after taxes." Got it.
#
# My approach is straightforward: I'll scan the document for tables and sections that explicitly mention "Statutory Profit After Tax" or variations like "Statutory Profit for the year," focusing on the 2024 figures.  I know from experience that financial reports often use different formats and language, so I need to be thorough.
#
# My initial scan reveals some promising leads. Page 4, in the "Financial and Operational Highlights," mentions "$1.25 billion Statutory Profit After Tax" for FY24. That's a good starting point.  Page 5's "FINANCIAL PERFORMANCE" table presents "Statutory Profit/(Loss) After Tax" as $1,251 M for 2024, which looks consistent.
#
# Page 13's "RESULTS HIGHLIGHTS" section states: "Statutory Profit After Tax was $1,251 million." And the chart on Page 40 shows "$1,251 million" for the same metric.
#
# Looking deeper, page 68 presents the "Consolidated Income Statement" table, and there it is: "Statutory profit for the year" as 1,251 $M for 2024. The same table is on page 69.  Page 106 gives the same figure, although this includes only the parent and the controlled entities, not the whole group. Page 109 provides the value for the parent entity only.
#
# Since the instruction states to use the values of the reporting company's group where available, I'll go with the consolidated figures.
#
# The value on page 68 is the most appropriate. From the "Consolidated Income Statement", I find the value I need: "Statutory profit for the year" is 1,251 $M. That's precisely what the prompt requests.
#
# Considering the presentation's emphasis on clarity, "million AUD" or just "million" seems appropriate as the unit. Given that the text on page 13 is in the "RESULTS HIGHLIGHTS" section and uses language like "Statutory Profit After Tax was $1,251 million", I think that is the most relevant section to report from. Therefore, the answer is:
#
# Value: 1,251
# Unit: million AUD
# Page: 13, 68
# """,
#         thought=True
#       ),
#       Part(
#         text="""{
#   "isDisclosed": 1,
#   "indicator_id": "profit",
#   "value": "1,251",
#   "unit": "million AUD",
#   "page_number": "13",
#   "section": "Statutory Profit After Tax"
# }"""
#       ),
#     ],
#     role='model'
#   ),
#   finish_reason=<FinishReason.STOP: 'STOP'>,
#   index=0
# )] create_time=None model_version='gemini-2.5-flash' prompt_feedback=None response_id='r1HEaMXoNuex1MkP4N-sqAQ' usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=67,
#   prompt_token_count=37701,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=549
#     ),
#     ModalityTokenCount(
#       modality=<MediaModality.DOCUMENT: 'DOCUMENT'>,
#       token_count=37152
#     ),
#   ],
#   thoughts_token_count=844,
#   total_token_count=38612
# ) automatic_function_calling_history=None parsed=None
#
# --- Response 5 ---
# sdk_http_response=None candidates=[Candidate(
#   citation_metadata=CitationMetadata(
#     citations=[
#       Citation(
#         end_index=4338,
#         license='',
#         start_index=4129,
#         uri='https://www.listcorp.com/asx/qan/qantas-airways-limited/news/qantas-group-hy23-appendix-4d-and-interim-financial-report-2839506.html'
#       ),
#     ]
#   ),
#   content=Content(
#     parts=[
#       Part(
#         text="""**Initial Assessment and Search Strategy**
#
# Alright, let's break this down. The request is for Qantas Airways' total full-time employee count for 2024. That means I'm looking for hard numbers, preferably for the company itself, but group figures will work in a pinch. The document might use terms like "employees," "workforce," "headcount," or even break it down by department, so I'll need to be thorough. I'll focus on sections typically dealing with company metrics, HR disclosures, and the financial report. I'll prioritize tables and direct text over figures if I can.
#
# **Page-by-Page Analysis**
#
# I've gone through the document meticulously. First, the table of contents directs me to likely sections: "Financial and Operational Highlights," "Directors' Report," and anything sustainability- or workforce-related. The "Financial and Operational Highlights" section (page 4) proved to be financial numbers, not employee figures.  Page 5 contained general statistics.  Page 6's Chair's Message mentioned "More than 29,000 employees across the Qantas Group as of FY2412" which is from the prompt, but it's not actually in the document. Page 8 mentioned an *increase* of 2,000 employees, but not a total.  Pages 10-12, the Board of Directors, showed biographical information, no employee totals. I continued this systematic search through the "Review of Operations" (Pages 13-25), the "Condensed Corporate Governance Statement" (Pages 26-27), the "Directors' Report" (Pages 28-32), and the "Remuneration Report" (Pages 34-64), among others.  I looked at financial statements and associated notes from page 65 onwards. There were mentions of "employees" throughout, but never a hard, quantifiable number for 2024. I was especially diligent in checking the "Salaries, wages, and other benefits" (page 68) because that is a very common place to put headcount figures.
#
# **Outcome**
#
# Unfortunately, despite an exhaustive search, the exact number requested — the total number of full-time Qantas Airways employees (or the Qantas Group) for 2024—is not explicitly stated in this document. The document alludes to employees, their importance, and mentions of workforce in various ways, but a definitive headcount figure is missing. I also tried an exact search for "More than 29,000 employees across the Qantas Group as of FY2412", a suggested term, and the phrase is not in the document itself. I was hopeful for an early number on page 8 regarding the *increase* in employees but that didn't provide any useful information on the total count for 2024.
# """,
#         thought=True
#       ),
#       Part(
#         text="""{
#   "isDisclosed": 0,
#   "indicator_id": "employees",
#   "value": "N/A",
#   "unit": "N/A",
#   "page_number": "N/A",
#   "section": "N/A"
# }"""
#       ),
#     ],
#     role='model'
#   ),
#   finish_reason=<FinishReason.STOP: 'STOP'>,
#   index=0
# )] create_time=None model_version='gemini-2.5-flash' prompt_feedback=None response_id='vFHEaLSkCuek1MkPhavzEA' usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=65,
#   prompt_token_count=37787,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=635
#     ),
#     ModalityTokenCount(
#       modality=<MediaModality.DOCUMENT: 'DOCUMENT'>,
#       token_count=37152
#     ),
#   ],
#   thoughts_token_count=3986,
#   total_token_count=41838
# ) automatic_function_calling_history=None parsed=None
