# %%
from Gemini import generatePromptsDictionary
import io
from Fullcontext_main import retrieveCompanyYearReports
from google import genai
client = genai.Client()

companyYearReports = retrieveCompanyYearReports("Airlines", "QuantasAirways", "2024")
prompts = {}

for doc in companyYearReports:
    print(f"Now prompting document: {doc.company_name} {doc.period} {doc.topic} {doc.mimetype} {doc.counter} ")

    doc_io = io.BytesIO(doc.file_value)
    uploaded_doc =  client.files.upload(
        file=doc_io,
        config=dict(
            mime_type=doc.mimetype)
    )
    print(f"Uploaded doc: {uploaded_doc.name} with MIME type: {uploaded_doc.mime_type}")

    prompts = generatePromptsDictionary(doc)
# Out:
# Download 100 of 2024.pdf application/pdf
# Download 100 of 2024.pdf application/pdf
# Now prompting document: QuantasAirways 2024 Topic.ESG application/pdf 1
# Uploaded doc: files/oizl47yxa8bt with MIME type: application/pdf
# Now prompting document: QuantasAirways 2024 Topic.FINANCIAL application/pdf 1
# Uploaded doc: files/vk1gmtbztotd with MIME type: application/pdf

# %%
from Gemini import IndicatorExtraction

requests_data = []

for indicatorID in prompts:
    request = {
        "key": indicatorID,
        "request": {
            "contents": [{
                "parts": [
                    {"text": prompts[indicatorID]},
                    {"file_data": {"file_uri": uploaded_doc.uri, "mime_type": uploaded_doc.mime_type}}
                ]
            }],
        "generationConfig": {
            "thinking_config": {
                  "include_thoughts": True,
                  "thinking_budget": -1
            },
            "response_mime_type": "application/json",
            "response_json_schema": IndicatorExtraction.model_json_schema()
        }
        }
    }
    requests_data.append(request)

print(requests_data)
# Out:
# [{'key': 'environmental_ex', 'request': {'contents': [{'parts': [{'text': '"Extract the following metric from the provided document:\n      -Money (OpEx, CapEx) used for environmental purposes (EU Taxonomy aligned CapEx and OpEx starting in 2024) of the reporting company QuantasAirways for the year 2024.\n      \n      Metric-specific instructions:\n      OpEx, CapEx used for environmental purposes (Taxonomy aligned). Specifically NOT money invested in carbon credits and offsets, those are already covered in the carbon_credits_offsets indicator. This value may also be specified as total expenses for environmental purposes.\n      From the year 2024 on, you can expect report to include figures of invested CapEx and OpEx that are aligned with climate friendly target according to the EU taxonomy. Prior to this year, general figures for investment in environment causes are sufficient. You should look for tables describing the Operational Expenditure and the Capital Expanditure in the requested period. Find the taxonomy-eligeble and taxonomy-aligned acitivites. You may have to add up the taxonomy-eligeble and taxonomy-aligned OpEx and the taxonomy-eligeble and taxonomy-aligned CapEx. You may have to add up environmental investments and environmental expenses to calculcate the total amount of money spent on environmental purposes.\n      \n      Suggested searchwords (you should still come up with your own searchwords):\n      Environmental Accounting for Fiscal 2022, Investments and operating costs – Environment (2018 – 2022), GM, 2022, Total , The total environmental and decommissioning provision comprises:, ?, A. Eligible activities in accordance with the taxonomy A.1. Environmentally sustainable activities (that align with the taxonomy), Environmental investments and expenses, Environmental protection input, Funds invested in environmental protection, Qantas Climate Fund committed, Total cash capital expenditures for 2023 Environmental\n      \n      General instructions:\n      -Use the provided document as a source of metrics\n      -Only consider english text\n      -You are not an expert at interpreting figures. You are much better at reading tables and text. Knowing this, you prefer reading information from tables and text over using figures, if possible.\n      -Hint: Look for tables in the Appendix and Annexes section of the reports, which can often be found in the last chapter of the documents. Look for tables in sections such as GRI indicatos, SASB Indicators, TCFD Indicators. These tables contain reliable and easy to digest information.\n      -Prefer values in metric tons over values the american short tons\n      -Prefer values in liters over values in gallons\n      -If there are values for the reporting company itself and for the reporting companies group available, use the values of the companies group.\n\n      Response Requirements:\n      -You are only allowed to return a single json object in your response, you can never return multiple results.\n      -Regarding the "is_disclosed" key: If the Information we are looking for is not disclosed in the document, set the is_disclosed field to 0.\n      -Regarding the "page_number" key: Provide the page number, where the respective information was found. \n      -Regarding the "section" key: Provide the text section where you found the information.\n      -The required output format is JSON.\n      \n      Example Output:\n      {            \n            "is_disclosed": 1, \n            "indicator_id": "environmental_ex":,\n            "value": "1.695",\n            "unit": "SEK Millions",\n            "page_number": "92",\n            "section" : "Capital expenditure of environmentally sustainable activities (Taxonomy-aligned) \n(A.1) 832  Operational expenditure of environmentally sustainable activities (Taxonomy\naligned) (A.1) 863"\n      }'}, {'file_data': {'file_uri': 'https://generativelanguage.googleapis.com/v1beta/files/vk1gmtbztotd', 'mime_type': 'applicat ...

# %%
import json

json_file_path = 'batch_requests_with_pdfs.json'

print(f"\nCreating JSONL file: {json_file_path}")
with open(json_file_path, 'w') as f:
    for req in requests_data:
        f.write(json.dumps(req) + '\n')

print(f"Uploading JSONL file: {json_file_path}")
batch_input_file = client.files.upload(
    file=json_file_path
    )
print(f"Uploaded JSONL file: {batch_input_file.name}")

print("\nCreating batch job...")
try:
    batch_job_from_file = client.batches.create(
        model="gemini-2.5-flash",
        src=batch_input_file.name,
        config={
            'display_name': 'quantas_batch_file_with_thinking_corrected_with_json_schema',
        }
    )
except Exception as e:
    print(e)
    print(e.message)
print(f"Created batch job from file: {batch_job_from_file.name}")
print("You can now monitor the job status using its name.")
# Out:
# Creating JSONL file: batch_requests_with_pdfs.json
# Uploading JSONL file: batch_requests_with_pdfs.json
# Uploaded JSONL file: files/2ab9n0303b8d
#
# Creating batch job...
# Created batch job from file: batches/11wqncexbtisoa2rrbvc9tqrtcm4qb1wxv25
# You can now monitor the job status using its name.

# %%
# Use the name of the job you want to check
# e.g., inline_batch_job.name from the previous step
job_name0 = "batches/68ohlbuc7numz7ketcvkwizg4dh8povs8eoa"  # (e.g. 'batches/your-batch-id')
job_name = "batches/zi9hlczk1uwzljrevytef2qwqw41djv4wfnq"  # (e.g. 'batches/your-batch-id')
batch_job_from_file = client.batches.get(name=job_name)

import time

completed_states = set([
    'JOB_STATE_SUCCEEDED',
    'JOB_STATE_FAILED',
    'JOB_STATE_CANCELLED',
    'JOB_STATE_EXPIRED',
])

while batch_job_from_file.state.name not in completed_states:
  print(f"Current state: {batch_job_from_file.state.name}")
  time.sleep(30) # Wait for 30 seconds before polling again

print(f"Job finished with state: {batch_job_from_file.state.name}")
if batch_job_from_file.state.name == 'JOB_STATE_FAILED':
    print(f"Error: {batch_job_from_file.error}")
# Out:
# Job finished with state: JOB_STATE_SUCCEEDED

# %%
completed_states = set([
    'JOB_STATE_SUCCEEDED',
    'JOB_STATE_FAILED',
    'JOB_STATE_CANCELLED',
    'JOB_STATE_EXPIRED',
])

print("Listing recent batch jobs:\n")

# Note: The list API currently doesn't return inlined_responses.
# As a workaround,you can make a `get` call for inline jobs to see their results.
batches = client.batches.list(config={'page_size': 10})

for b in batches.page:
    print(f"Job Name: {b.name}")
    print(f"  - Display Name: {b.display_name}")
    print(f"  - State: {b.state.name}")
    print(f"  - Create Time: {b.create_time.strftime('%Y-%m-%d %H:%M:%S')}")
    if b.state.name in completed_states:
        print(f"  - End Time: {b.end_time.strftime('%Y-%m-%d %H:%M:%S')}")




    # Check if it was an inline job (no destination file)
    if b.dest is not None:
      if not b.dest.file_name:
        full_job = client.batches.get(name=b.name)
        if full_job.inlined_responses:
            print("  - Type: Inline ({} responses)".format(len(full_job.inlined_responses)))
      else:
          print(f"  - Type: File-based (Output: {b.dest.file_name})")

    print("-" * 20)
# Out:
# Listing recent batch jobs:
#
# Job Name: batches/11wqncexbtisoa2rrbvc9tqrtcm4qb1wxv25
#   - Display Name: quantas_batch_file_with_thinking_corrected_with_json_schema
#   - State: JOB_STATE_SUCCEEDED
#   - Create Time: 2025-09-12 18:31:09
#   - End Time: 2025-09-12 18:39:49
#   - Type: File-based (Output: files/batch-11wqncexbtisoa2rrbvc9tqrtcm4qb1wxv25)
# --------------------
# Job Name: batches/i9m070qk0ebqez5f3my485jreq4r6jrhut3x
#   - Display Name: quantas_batch_file_with_thinking_corrected
#   - State: JOB_STATE_SUCCEEDED
#   - Create Time: 2025-09-12 18:25:13
#   - End Time: 2025-09-12 18:39:55
#   - Type: File-based (Output: files/batch-i9m070qk0ebqez5f3my485jreq4r6jrhut3x)
# --------------------
# Job Name: batches/5dfzbzpknv9dkwjdy3sx1w9g21u409g92aoj
#   - Display Name: my-batch-job-with-file-and-thoughts-thinking_config
#   - State: JOB_STATE_SUCCEEDED
#   - Create Time: 2025-09-12 16:59:15
#   - End Time: 2025-09-12 17:00:40
#   - Type: File-based (Output: files/batch-5dfzbzpknv9dkwjdy3sx1w9g21u409g92aoj)
# --------------------
# Job Name: batches/nm1ycsfts46b6vh2090bh4xyo9plyvs0dr06
#   - Display Name: quantas-airlines-inline-batch-test1
#   - State: JOB_STATE_SUCCEEDED
#   - Create Time: 2025-09-12 16:51:34
#   - End Time: 2025-09-12 17:00:44
# --------------------
# Job Name: batches/ff0deax8tnaay5rr0gqkn6g22pl3pd4orcrk
#   - Display Name: extraction_attempt_3
#   - State: JOB_STATE_SUCCEEDED
#   - Create Time: 2025-09-11 22:12:59
#   - End Time: 2025-09-12 10:09:13
#   - Type: File-based (Output: files/batch-ff0deax8tnaay5rr0gqkn6g22pl3pd4orcrk)
# --------------------
# Job Name: batches/vnb8p71ws0ug2mgdkb6vmo11xlxspy40okyd
#   - Display Name: my-batch-job-with-file-and-thoughts-thinking_config
#   - State: JOB_STATE_SUCCEEDED
#   - Create Time: 2025-09-11 16:44:56
#   - End Time: 2025-09-11 17:48:30
#   - Type: File-based (Output: files/batch-vnb8p71ws0ug2mgdkb6vmo11xlxspy40okyd)
# --------------------
# Job Name: batches/f9twk9y9jhwrgfyjrpq9h3ucnqr5cypgorio
#   - Display Name: my-batch-job-with-file-and-thoughts
#   - State: JOB_STATE_SUCCEEDED
#   - Create Time: 2025-09-11 00:14:25
#   - End Time: 2025-09-11 03:29:17
#   - Type: File-based (Output: files/batch-f9twk9y9jhwrgfyjrpq9h3ucnqr5cypgorio)
# --------------------
# Job Name: batches/zi9hlczk1uwzljrevytef2qwqw41djv4wfnq
#   - Display Name: my-batch-job-with-file
#   - State: JOB_STATE_SUCCEEDED
#   - Create Time: 2025-09-10 23:57:10
#   - End Time: 2025-09-11 03:16:01
#   - Type: File-based (Output: files/batch-zi9hlczk1uwzljrevytef2qwqw41djv4wfnq)
# --------------------
# Job Name: batches/68ohlbuc7numz7ketcvkwizg4dh8povs8eoa
#   - Display Name: my-batch-job-with-image
#   - State: JOB_STATE_SUCCEEDED
#   - Create Time: 2025-09-10 22:46:36
#   - End Time: 2025-09-11 03:12:10
#   - Type: File-based (Output: files/batch-68ohlbuc7numz7ketcvkwizg4dh8povs8eoa)
# --------------------
# Job Name: batches/juotfcgfm48su8533h4mri00hhvn2vsr8zzz
#   - Display Name: file-upload-job-1
#   - State: JOB_STATE_SUCCEEDED
#   - Create Time: 2025-09-10 19:51:39
#   - End Time: 2025-09-11 03:19:59
#   - Type: File-based (Output: files/batch-juotfcgfm48su8533h4mri00hhvn2vsr8zzz)
# --------------------

# %%
import json

batch_job = client.batches.get(name="batches/11wqncexbtisoa2rrbvc9tqrtcm4qb1wxv25")

if batch_job.state.name == 'JOB_STATE_SUCCEEDED':
    # The output is in another file.
    result_file_name = batch_job.dest.file_name
    print(f"Results are in file: {result_file_name}")

    print("\nDownloading and parsing result file content...")
    file_content_bytes = client.files.download(file=result_file_name)
    file_content = file_content_bytes.decode('utf-8')

    # The result file is also a JSONL file. Parse and print each line.
    for line in file_content.splitlines():
      if line:
        parsed_response = json.loads(line)
        # Pretty-print the JSON for readability
        print(json.dumps(parsed_response, indent=2))
        print("-" * 20)
else:
    print(f"Job did not succeed. Final state: {batch_job.state.name}")
# Out:
# Results are in file: files/batch-11wqncexbtisoa2rrbvc9tqrtcm4qb1wxv25
#
# Downloading and parsing result file content...
# {
#   "key": "environmental_ex",
#   "response": {
#     "modelVersion": "gemini-2.5-flash",
#     "candidates": [
#       {
#         "content": {
#           "parts": [
#             {
#               "thought": true,
#               "text": "**QuantasAirways 2024 Environmental Expenditure Analysis**\n\nMy task is to locate and quantify \"Money (OpEx, CapEx) used for environmental purposes (EU Taxonomy aligned CapEx and OpEx starting in 2024)\" for Qantas Airways' 2024 reporting. I've focused my search on environmental investments, CapEx, OpEx, and importantly, EU Taxonomy alignment.\n\nI began by searching the document for key terms like \"environmental purposes,\" \"CapEx,\" \"OpEx,\" and \"taxonomy.\" I systematically reviewed the document, meticulously noting any mention of environmental spending or investments. The instructions are specific: exclude carbon credits and offsets, as those have their own indicator. I'm looking for *explicit* environmental CapEx and OpEx, particularly those aligned with the EU Taxonomy, starting from 2024.\n\nEarly sections (Pages 4, 6, 8, 13, 14) discussed general investments and financial frameworks, but nothing specific to environmental CapEx or OpEx was found. Page 15 mentioned ESG considerations, but without monetary figures. Page 16 mentions carbon-offsetting expenses (excluded) and SAF, but doesn't quantify them separately from offsets. Page 23 details climate strategies, including fleet modernization (potentially CapEx), but no monetary values are provided. Pages 41 and 42 present a \"Financial contribution from Business to Business (B2B) Offsets and sustainable aviation fuel (SAF) programs\" totaling $4.3 million. However, the instruction explicitly excludes carbon offsets. Since SAF is bundled with offsets, and the document doesn't provide a way to separate the SAF portion, I can't use this value.  Pages 42 and 43 reiterate the programs without providing disaggregated monetary values, and Page 75 discusses climate change impacts and capital expenditure for more fuel-efficient aircraft without separating out the environmental portion.\n\nThe key missing element is any explicit EU Taxonomy alignment. Despite being a 2024 annual report, the document does not mention \"EU Taxonomy\" or taxonomy-aligned spending. Given the instructions and the document's structure, I would expect to find such information if it were disclosed.\n\nMy conclusion: based on this thorough review, the required information appears to be not disclosed in the provided document. Therefore, `isDisclosed` should be set to 0.\n"
#             },
#             {
#               "text": "{\n  \"indicator_id\": \"environmental_capex_opex\",\n  \"value\": \"Not disclosed\",\n  \"unit\": \"Not disclosed\",\n  \"page_number\": \"Not disclosed\",\n  \"section\": \"Not disclosed\",\n  \"isDisclosed\": 0\n}"
#             }
#           ],
#           "role": "model"
#         },
#         "index": 0,
#         "citationMetadata": {
#           "citationSources": [
#             {
#               "uri": "https://www.listcorp.com/asx/qan/qantas-airways-limited/news/qantas-group-fy24-appendix-4e-and-preliminary-final-report-3076215.html",
#               "license": "",
#               "endIndex": 2532,
#               "startIndex": 2279
#             },
#             {
#               "license": "",
#               "uri": "https://www.listcorp.com/asx/qan/qantas-airways-limited/news/qantas-group-hy24-appendix-4d-and-interim-financial-report-2996874.html",
#               "startIndex": 2792,
#               "endIndex": 3081
#             },
#             {
#               "startIndex": 3029,
#               "endIndex": 3365,
#               "license": "",
#               "uri": "https://www.listcorp.com/asx/qan/qantas-airways-limited/news/qantas-group-fy22-appendix-4e-and-preliminary-final-report-2752657.html"
#             },
#             {
#               "endIndex": 3529,
#               "uri": "https://www.listcorp.com/asx/qan/qantas-airways-limited/news/qantas-group-hy23-appendix-4d-and-interim-financial-report-2839506.html",
#               "startIndex": 3252,
#               "license": ""
#             },
#             {
#               "endIndex": 3776,
#               "license": "",
#               "uri": "https://www.listcorp.com/asx/qan/qantas-airways-limited/news/qantas-group-hy24-appendix-4d-and-interim-financial-report-2996874.html",
#               "startIndex": 3416
#             },
#             {
#               "startIndex": 7790,
#               "license": "",
#               "endIndex": 8457,
#               "uri": ""
#             }
#           ]
#         },
#         "finishReason": "STOP"
#       }
#     ],
#     "usageMetadata": {
#       "promptTokensDetails": [
#         {
#           "modality": "TEXT",
#           "tokenCount": 813
#         },
#         {
#           "tokenCount": 37152,
#           "modality": "DOCUMENT"
#         }
#       ],
#       "totalTokenCount": 40176,
#       "candidatesTokenCount": 66,
#       "thoughtsTokenCount": 2145,
#       "promptTokenCount": 37965
#     },
#     "responseId": "9GjEaPnHOZyn1MkPwu_38A8"
#   }
# }
# --------------------
# {
#   "response": {
#     "usageMetadata": {
#       "candidatesTokenCount": 64,
#       "thoughtsTokenCount": 2184,
#       "totalTokenCount": 39958,
#       "promptTokenCount": 37710,
#       "promptTokensDetails": [
#         {
#           "tokenCount": 558,
#           "modality": "TEXT"
#         },
#         {
#           "tokenCount": 37152,
#           "modality": "DOCUMENT"
#         }
#       ]
#     },
#     "modelVersion": "gemini-2.5-flash",
#     "candidates": [
#       {
#         "finishReason": "STOP",
#         "index": 0,
#         "citationMetadata": {
#           "citationSources": [
#             {
#               "uri": "https://www.listcorp.com/asx/qan/qantas-airways-limited/news/qantas-group-hy24-appendix-4d-and-interim-financial-report-2996874.html",
#               "endIndex": 2994,
#               "startIndex": 2705,
#               "license": ""
#             },
#             {
#               "startIndex": 2942,
#               "license": "",
#               "endIndex": 3278,
#               "uri": "https://www.listcorp.com/asx/qan/qantas-airways-limited/news/qantas-group-fy22-appendix-4e-and-preliminary-final-report-2752657.html"
#             },
#             {
#               "license": "",
#               "endIndex": 3442,
#               "uri": "https://www.listcorp.com/asx/qan/qantas-airways-limited/news/qantas-group-hy23-appendix-4d-and-interim-financial-report-2839506.html",
#               "startIndex": 3165
#             },
#             {
#               "uri": "https://www.listcorp.com/asx/qan/qantas-airways-limited/news/qantas-group-hy24-appendix-4d-and-interim-financial-report-2996874.html",
#               "endIndex": 3689,
#               "license": "",
#               "startIndex": 3329
#             },
#             {
#               "startIndex": 3710,
#               "uri": "https://www.listcorp.com/asx/qan/qantas-airways-limited/news/qantas-group-hy24-appendix-4d-and-interim-financial-report-2996874.html",
#               "license": "",
#               "endIndex": 3935
#             },
#             {
#               "uri": "https://www.listcorp.com/asx/qan/qantas-airways-limited/news/qantas-group-fy22-appendix-4e-and-preliminary-final-report-2752657.html",
#               "startIndex": 8834,
#               "license": "",
#               "endIndex": 9203
#             }
#           ]
#         },
#         "content": {
#           "parts": [
#             {
#               "thought": true,
#               "text": "**Quantifying Low-Carbon Revenue for Qantas Airways in 2024**\n\nOkay, here's the breakdown of my thinking as I navigated this document. My task was to isolate the \"Total revenue from products/services designed for low-carbon economy\" for Qantas Airways for the fiscal year 2024. I was focused on keywords like \"low-carbon,\" \"sustainable,\" and any financial metrics related to these areas.\n\nMy initial scan through the document (pages 3-24) was mostly fruitless. While there was plenty of discussion about sustainability initiatives, climate action plans, and fleet efficiency, direct revenue figures for low-carbon products or services were absent. I noted the mention of the Airbus A220's fuel efficiency, but that was about operational improvements, not revenue generation. I went through the financial highlights and the Group Underlying Income Statement Summary, but total revenue was listed, with no breakdown. Similarly, the MATERIAL BUSINESS RISKS section covered climate-related risks, but again, no specific revenue figures were present.\n\nMy breakthrough came on page 41 and, specifically, page 42, within the \"Performance Assessment of 2023/24 Group Scorecard Measures - Climate\" section. Here, I found a clear statement: \"The SAF Corporate Coalition achieved revenue of $3.3 million.\" This was explicitly labeled as *revenue* generated from the SAF Corporate Coalition, which aligns perfectly with my criteria of revenue from low-carbon related activity. The document describes it as a business-to-business product.\n\nWhile I saw a broader \"total program mitigations\" value of $4.3 million (which included other elements like the \"Qantas Future Planet program\"), the explicit revenue from the SAF Corporate Coalition of $3.3 million was the most direct and accurate answer to the specific prompt. It's revenue generated by the reporting company.\n\nTherefore, my final determination is: **$3.3 million** is the \"lowCarbon_revenue\" I was looking for, found on page 42, within the \"Performance Assessment of 2023/24 Group Scorecard Measures - Climate\" section.\n"
#             },
#             {
#               "text": "{\"indicator_id\": \"lowCarbon_revenue\", \"value\": \"3.3\", \"unit\": \"$M\", \"page_number\": \"42\", \"section\": \"Performance Assessment of 2023/24 Group Scorecard Measures - Climate\", \"isDisclosed\": 1}"
#             }
#           ],
#           "role": "model"
#         }
#       }
#     ],
#     "responseId": "8WjEaNSYJOit1MkP0r7XuQQ"
#   },
#   "key": "lowCarbon_revenue"
# }
# --------------------
# {
#   "response": {
#     "usageMetadata": {
#       "thoughtsTokenCount": 484,
#       "promptTokenCount": 37657,
#       "candidatesTokenCount": 52,
#       "totalTokenCount": 38193,
#       "promptTokensDetails": [
#         {
#           "modality": "TEXT",
#           "tokenCount": 505
#         },
#         {
#           "modality": "DOCUMENT",
#           "tokenCount": 37152
#         }
#       ]
#     },
#     "responseId": "62jEaLb7HJem1MkP6YLmgQ8",
#     "modelVersion": "gemini-2.5-flash",
#     "candidates": [
#       {
#         "finishReason": "STOP",
#         "index": 0,
#         "content": {
#           "role": "model",
#           "parts": [
#             {
#               "thought": true,
#               "text": "**Revenue Analysis for QuantasAirways in 2024**\n\nOkay, so the user wants the \"Revenue for the reporting Period of the reporting company QuantasAirways for the year 2024.\"  I need to find \"Revenue\" or similar terms and then filter for the year 2024. Let's see...\n\nI've quickly scanned the document and it looks like Page 5 has a \"Five-Year History\" table with \"Revenue and other income.\" Hmm, possibly a good starting point. Page 13 mentions the \"financial year 2023/24,\" which is a close match, so I'll keep an eye on that. Page 16 looks interesting with a \"Group Underlying Income Statement Summary\" table; it shows \"Revenue\" for June 2024. Pages 19, 20, and 21 have \"Revenue\" broken down by Qantas Domestic, International, Jetstar, and Loyalty. Finally, Page 68 has a \"Consolidated Income Statement\" with \"Revenue and other income\" for both 2024 and 2023. This is what I was hoping to find!\n\nNow, looking closer at Page 68's \"Consolidated Income Statement,\" the \"Revenue and other income\" for 2024 is listed as \"21,939\" $M. That seems to be the total group revenue. Excellent! The reporting period is \"For the year ended 30 June 2024,\" which matches perfectly.\n\nI'm checking if this value appears elsewhere to ensure consistency.  Looking back at Page 5, I confirm \"Revenue and other income\" for 2024 is the same \"21,939\" $M. And page 16 also confirms the value.\n\nSince it's consistent across multiple sections, I feel confident using the figure from the \"Consolidated Income Statement\" as it's the primary financial statement.\n\nThe value is indeed \"21,939\", and the units are millions (\"M\") of Australian Dollars (AUD). The document mentions \"Australian dollars\" on page 74 for good measure.\n\nSo, here's my answer: **AUD 21,939 million is the Revenue for the year ended June 30, 2024 (Page 68, Consolidated Income Statement).**\n"
#             },
#             {
#               "text": "{\"indicator_id\": \"revenue\", \"value\": \"21,939\", \"unit\": \"AUD millions\", \"page_number\": \"68\", \"section\": \"Consolidated Income Statement\", \"isDisclosed\": 1}"
#             }
#           ]
#         }
#       }
#     ]
#   },
#   "key": "revenue"
# }
# --------------------
# {
#   "response": {
#     "modelVersion": "gemini-2.5-flash",
#     "usageMetadata": {
#       "promptTokensDetails": [
#         {
#           "modality": "TEXT",
#           "tokenCount": 549
#         },
#         {
#           "modality": "DOCUMENT",
#           "tokenCount": 37152
#         }
#       ],
#       "candidatesTokenCount": 51,
#       "totalTokenCount": 38775,
#       "promptTokenCount": 37701,
#       "thoughtsTokenCount": 1023
#     },
#     "candidates": [
#       {
#         "index": 0,
#         "finishReason": "STOP",
#         "content": {
#           "role": "model",
#           "parts": [
#             {
#               "thought": true,
#               "text": "**Determining Qantas Airways' Net Income After Taxes for 2024**\n\nMy task is to pinpoint Qantas Airways' \"Profit for the reporting Period,\" specifically, their net income after taxes (also known as \"Statutory Profit/(Loss) After Tax\") for the fiscal year 2024. The user has specifically requested the group's consolidated figures, not the parent company's or subsidiary companies' financial reports.\n\nMy approach involved searching the document for variations of the target metric, such as \"Statutory Profit After Tax\" and \"Statutory profit for the year.\" I quickly located several promising entries.\n\nPage 4's \"Financial and Operational Highlights\" section immediately provided a key value: \"$1.25 billion Statutory Profit After Tax\" for FY24. Page 5's table of \"FINANCIAL PERFORMANCE1\" for the \"Qantas Annual Report 2024\" reinforces this with a \"Statutory Profit/(Loss) After Tax\" of \"1,251 $M\" for 2024. Page 68, the \"Consolidated Income Statement,\" confirms this value, listing \"Statutory profit for the year\" as \"1,251 $M\" for the relevant year. Page 13's \"RESULTS HIGHLIGHTS\" aligns, stating \"Statutory Profit After Tax was $1,251 million.\"\n\nI've taken the instruction to use the group's values for this specific request into consideration. Page 106 and 109 provides the Parent entity and Deed of Cross Guarantee. However, these figures are for the parent and consolidated entity, respectively. Page 5, and 68 are the best fit for this scenario.\n\nThe term \"Statutory Profit After Tax\" generally encompasses net income after all taxes, including both continuing and discontinued operations, which aligns perfectly with the user's request for \"net income after taxes, not income from continuing operations.\"\n\nTherefore, I have confirmed the value is \"1,251\", unit \"AUD millions\", and can be found on page \"68\" within the \"Consolidated Income Statement,\" specifically listed as \"Statutory profit for the year\" for the fiscal year 2024. Page 5 is also a great source for this information. The highlighted section on Page 4 further supports this. I can confidently say that the information \"isDisclosed.\"\n"
#             },
#             {
#               "text": "{\"indicator_id\": \"profit\", \"value\": \"1,251\", \"unit\": \"AUD millions\", \"page_number\": \"68\", \"section\": \"Consolidated Income Statement\", \"isDisclosed\": 1}"
#             }
#           ]
#         }
#       }
#     ],
#     "responseId": "6mjEaJKDDIiY1MkP-tul4AM"
#   },
#   "key": "profit"
# }
# --------------------
# {
#   "key": "employees",
#   "response": {
#     "responseId": "9WjEaI6oNpyc1MkPxv6iCA",
#     "modelVersion": "gemini-2.5-flash",
#     "usageMetadata": {
#       "candidatesTokenCount": 34,
#       "thoughtsTokenCount": 2520,
#       "totalTokenCount": 40341,
#       "promptTokensDetails": [
#         {
#           "modality": "TEXT",
#           "tokenCount": 635
#         },
#         {
#           "modality": "DOCUMENT",
#           "tokenCount": 37152
#         }
#       ],
#       "promptTokenCount": 37787
#     },
#     "candidates": [
#       {
#         "index": 0,
#         "citationMetadata": {
#           "citationSources": [
#             {
#               "uri": "https://www.listcorp.com/asx/qan/qantas-airways-limited/news/qantas-group-hy23-appendix-4d-and-interim-financial-report-2839506.html",
#               "license": "",
#               "startIndex": 1241,
#               "endIndex": 1450
#             },
#             {
#               "license": "",
#               "startIndex": 1788,
#               "endIndex": 1996,
#               "uri": "https://investor.qantas.com/FormBuilder/_Resource/_module/doLLG5ufYkCyEPjF1tpgyw/file/annual-reports/2021-Annual-Report.pdf"
#             },
#             {
#               "license": "",
#               "uri": "https://www.listcorp.com/asx/qan/qantas-airways-limited/news/qantas-group-hy23-appendix-4d-and-interim-financial-report-2839506.html",
#               "endIndex": 5291,
#               "startIndex": 5082
#             },
#             {
#               "endIndex": 6214,
#               "uri": "https://openbriefing.com.au/AsxDownload.aspx?pdfUrl=Report%2FComNews%2F20220909%2F02566390.pdf",
#               "startIndex": 5828,
#               "license": ""
#             },
#             {
#               "startIndex": 6545,
#               "endIndex": 6781,
#               "license": "",
#               "uri": "https://openbriefing.com.au/AsxDownload.aspx?pdfUrl=Report%2FComNews%2F20220909%2F02566390.pdf"
#             },
#             {
#               "endIndex": 6963,
#               "startIndex": 6727,
#               "uri": "https://openbriefing.com.au/AsxDownload.aspx?pdfUrl=Report%2FComNews%2F20220909%2F02566390.pdf",
#               "license": ""
#             }
#           ]
#         },
#         "finishReason": "STOP",
#         "content": {
#           "parts": [
#             {
#               "text": "**Assessment of Qantas Airways Employee Count for 2024**\n\nMy analysis focuses on identifying the total number of full-time employees (including permanent and temporary) within Qantas Airways for the year 2024, as per the user's instructions.  I've thoroughly searched the provided document, prioritizing tables and key sections like the CEO's Message and \"Our People.\" I also utilized the suggested keyword \"More than 29,000 employees across the Qantas Group as of FY24\" as a potential target.\n\nMy investigation led me through numerous pages, including key statistical tables, financial statements, and sections dedicated to employee relations. However, despite an exhaustive search, I was unable to locate a definitive, consolidated figure representing the total number of employees, full-time or otherwise, for the specific period or fiscal year 2024. Although the document mentions employee increases and employee-related programs, the precise number requested is not explicitly stated.\n\nTherefore, based on this comprehensive review of the provided document, I must conclude that the specific metric, \"total full-time employees\" for Qantas Airways in 2024, is not directly disclosed within the extract.  The search yielded references to employee count increases and programs, but the requested total is not apparent.\n",
#               "thought": true
#             },
#             {
#               "text": "{\"indicator_id\": \"employees\", \"value\": \"\", \"unit\": \"\", \"page_number\": \"\", \"section\": \"\", \"isDisclosed\": 0}"
#             }
#           ],
#           "role": "model"
#         }
#       }
#     ]
#   }
# }
# --------------------
