# %%
from Gemini import generatePromptsDictionary
import io
from Fullcontext_main import retrieveCompanyYearReports
from google import genai
client = genai.Client()

companyYearReports = retrieveCompanyYearReports("Airlines", "QuantasAirways", "2024")

for doc in companyYearReports:
    print(f"Now prompting document: {doc.company_name} {doc.period} {doc.topic} {doc.mimetype} {doc.counter} ")

    doc_io = io.BytesIO(doc.file_value)
    uploaded_doc =  client.files.upload(
        file=doc_io,
        config=dict(
            mime_type=doc.mimetype)
    )
    print(f"Uploaded doc: {uploaded_doc.name} with MIME type: {uploaded_doc.mime_type}")

    prompts = generatePromptsDictionary(doc)
# Out:
# Download 100 of 2024.pdf application/pdf
# Download 100 of 2024.pdf application/pdf
# Now prompting document: QuantasAirways 2024 Topic.ESG application/pdf 1
# Uploaded doc: files/txx1gol65y36 with MIME type: application/pdf
# Now prompting document: QuantasAirways 2024 Topic.FINANCIAL application/pdf 1
# Uploaded doc: files/oyvoeiwpj5os with MIME type: application/pdf

# %%
from Gemini import IndicatorExtraction

requests_data = []

for indicatorID in prompts:
    request = {
        "key": indicatorID,
        "request": {
            "contents": [{
                "parts": [
                    {"text": prompts[indicatorID]},
                    {"file_data": {"file_uri": uploaded_doc.uri, "mime_type": uploaded_doc.mime_type}}
                ]
            }]
        },
        "generation_config": {
            "thinking_config": {
                  "include_thoughts": True,
            },
            "response_mime_type": "application/json",
            "response_schema": IndicatorExtraction.model_json_schema()
        }
    }
    requests_data.append(request)

print(requests_data)
# Out:
# [{'key': 'environmental_ex', 'request': {'contents': [{'parts': [{'text': '"Extract the following Information from the provided document:\n      -Money (OpEx, CapEx) used for environmental purposes (EU Taxonomy aligned CapEx and OpEx starting in 2024)\n\n      Provide the page number, where the respective information was found. \n      Also provide the text section where you found the information.\n      If the Information we are looking for is not disclosed in the document, set the is_disclosed field to 0.\n      The required output format is JSON.\n      Example:\n      {            \n            "is_disclosed": 1, \n            "indicator_id": "environmental_ex":,\n            "value": "1.695",\n            "unit": "SEK Millions",\n            "page_number": "92",\n            "section" : "Capital expenditure of environmentally sustainable activities (Taxonomy-aligned) \n(A.1) 832  Operational expenditure of environmentally sustainable activities (Taxonomy\naligned) (A.1) 863"\n      }'}, {'file_data': {'file_uri': 'https://generativelanguage.googleapis.com/v1beta/files/oyvoeiwpj5os', 'mime_type': 'application/pdf'}}]}]}, 'generation_config': {'thinking_config': {'include_thoughts': True}, 'response_mime_type': 'application/json', 'response_schema': {'properties': {'isDisclosed': {'default': 1, 'title': 'Isdisclosed', 'type': 'integer'}, 'indicator_id': {'title': 'Indicator Id', 'type': 'string'}, 'value': {'title': 'Value', 'type': 'string'}, 'unit': {'title': 'Unit', 'type': 'string'}, 'page_number': {'title': 'Page Number', 'type': 'string'}, 'section': {'title': 'Section', 'type': 'string'}}, 'required': ['indicator_id', 'value', 'unit', 'page_number', 'section'], 'title': 'IndicatorExtraction', 'type': 'object'}}}, {'key': 'lowCarbon_revenue', 'request': {'contents': [{'parts': [{'text': '"Extract the following Information from the provided document:\n      -Total tevenue from products/services designed for low-carbon economy\n\n      Provide the page number, where the respective information was found. \n      Also provide the text section where you found the information.\n      If the Information we are looking for is not disclosed in the document, set the is_disclosed field to 0.\n      The required output format is JSON.\n      Example:\n      {            \n            "is_disclosed": 1, \n            "indicator_id": "lowCarbon_revenue":,\n            "value": "85,990",\n            "unit": "SEK Millions",\n            "page_number": "92",\n            "section" : "A. Turnover of Taxonomy-eligible activities (A.1 + A.2) 85,990"\n      }'}, {'file_data': {'file_uri': 'https://generativelanguage.googleapis.com/v1beta/files/oyvoeiwpj5os', 'mime_type': 'application/pdf'}}]}]}, 'generation_config': {'thinking_config': {'include_thoughts': True}, 'response_mime_type': 'application/json', 'response_schema': {'properties': {'isDisclosed': {'default': 1, 'title': 'Isdisclosed', 'type': 'integer'}, 'indicator_id': {'title': 'Indicator Id', 'type': 'string'}, 'value': {'title': 'Value', 'type': 'string'}, 'unit': {'title': 'Unit', 'type': 'string'}, 'page_number': {'title': 'Page Number', 'type': 'string'}, 'section': {'title': 'Section', 'type': 'string'}}, 'required': ['indicator_id', 'value', 'unit', 'page_number', 'section'], 'title': 'IndicatorExtraction', 'type': 'object'}}}, {'key': 'revenue', 'request': {'contents': [{'parts': [{'text': '"Extract the following Information from the provided document:\n      -Revenue for the reporting Period\n\n      Provide the page number, where the respective information was found. \n      Also provide the text section where you found the information.\n      If the Information we are looking for is not disclosed in the document, set the is_disclosed field to 0.\n      The required output format is JSON.\n      Example:\n      {            \n            "is_disclosed": 1, \n            "indicator_id": "revenue":,\n            "value": "103,418",\n            "unit": "SEK millions",\n  ...

# %%
import json

json_file_path = 'batch_requests_with_pdfs.json'

print(f"\nCreating JSONL file: {json_file_path}")
with open(json_file_path, 'w') as f:
    for req in requests_data:
        f.write(json.dumps(req) + '\n')

print(f"Uploading JSONL file: {json_file_path}")
batch_input_file = client.files.upload(
    file=json_file_path
    )
print(f"Uploaded JSONL file: {batch_input_file.name}")

print("\nCreating batch job...")
batch_job_from_file = client.batches.create(
    model="gemini-2.5-flash",
    src=batch_input_file.name,
    config={
        'display_name': 'my-batch-job-with-file-and-thoughts-thinking_config',
    }
)
print(f"Created batch job from file: {batch_job_from_file.name}")
print("You can now monitor the job status using its name.")
# Out:
# Creating JSONL file: batch_requests_with_pdfs.json
# Uploading JSONL file: batch_requests_with_pdfs.json
# Uploaded JSONL file: files/4odmts83t579
#
# Creating batch job...
# Created batch job from file: batches/vnb8p71ws0ug2mgdkb6vmo11xlxspy40okyd
# You can now monitor the job status using its name.

# %%
# Use the name of the job you want to check
# e.g., inline_batch_job.name from the previous step
job_name0 = "batches/68ohlbuc7numz7ketcvkwizg4dh8povs8eoa"  # (e.g. 'batches/your-batch-id')
job_name = "batches/zi9hlczk1uwzljrevytef2qwqw41djv4wfnq"  # (e.g. 'batches/your-batch-id')
batch_job_from_file = client.batches.get(name=job_name)

import time

completed_states = set([
    'JOB_STATE_SUCCEEDED',
    'JOB_STATE_FAILED',
    'JOB_STATE_CANCELLED',
    'JOB_STATE_EXPIRED',
])

while batch_job_from_file.state.name not in completed_states:
  print(f"Current state: {batch_job_from_file.state.name}")
  time.sleep(30) # Wait for 30 seconds before polling again

print(f"Job finished with state: {batch_job_from_file.state.name}")
if batch_job_from_file.state.name == 'JOB_STATE_FAILED':
    print(f"Error: {batch_job_from_file.error}")
# Out:
# Current state: JOB_STATE_PENDING
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 18
#      16 while batch_job_from_file.state.name not in completed_states:
#      17   print(f"Current state: {batch_job_from_file.state.name}")
# ---> 18   time.sleep(30) # Wait for 30 seconds before polling again
#      20 print(f"Job finished with state: {batch_job_from_file.state.name}")
#      21 if batch_job_from_file.state.name == 'JOB_STATE_FAILED':
#
# KeyboardInterrupt:

# %%
completed_states = set([
    'JOB_STATE_SUCCEEDED',
    'JOB_STATE_FAILED',
    'JOB_STATE_CANCELLED',
    'JOB_STATE_EXPIRED',
])

print("Listing recent batch jobs:\n")

# Note: The list API currently doesn't return inlined_responses.
# As a workaround,you can make a `get` call for inline jobs to see their results.
batches = client.batches.list(config={'page_size': 10})

for b in batches.page:
    print(f"Job Name: {b.name}")
    print(f"  - Display Name: {b.display_name}")
    print(f"  - State: {b.state.name}")
    print(f"  - Create Time: {b.create_time.strftime('%Y-%m-%d %H:%M:%S')}")
    if b.state.name in completed_states:
        print(f"  - End Time: {b.end_time.strftime('%Y-%m-%d %H:%M:%S')}")




    # Check if it was an inline job (no destination file)
    if b.dest is not None:
      if not b.dest.file_name:
        full_job = client.batches.get(name=b.name)
        if full_job.inlined_responses:
            print("  - Type: Inline ({} responses)".format(len(full_job.inlined_responses)))
      else:
          print(f"  - Type: File-based (Output: {b.dest.file_name})")

    print("-" * 20)
# Out:
# Listing recent batch jobs:
#
# Job Name: batches/vnb8p71ws0ug2mgdkb6vmo11xlxspy40okyd
#   - Display Name: my-batch-job-with-file-and-thoughts-thinking_config
#   - State: JOB_STATE_SUCCEEDED
#   - Create Time: 2025-09-11 16:44:56
#   - End Time: 2025-09-11 17:48:30
#   - Type: File-based (Output: files/batch-vnb8p71ws0ug2mgdkb6vmo11xlxspy40okyd)
# --------------------
# Job Name: batches/f9twk9y9jhwrgfyjrpq9h3ucnqr5cypgorio
#   - Display Name: my-batch-job-with-file-and-thoughts
#   - State: JOB_STATE_SUCCEEDED
#   - Create Time: 2025-09-11 00:14:25
#   - End Time: 2025-09-11 03:29:17
#   - Type: File-based (Output: files/batch-f9twk9y9jhwrgfyjrpq9h3ucnqr5cypgorio)
# --------------------
# Job Name: batches/zi9hlczk1uwzljrevytef2qwqw41djv4wfnq
#   - Display Name: my-batch-job-with-file
#   - State: JOB_STATE_SUCCEEDED
#   - Create Time: 2025-09-10 23:57:10
#   - End Time: 2025-09-11 03:16:01
#   - Type: File-based (Output: files/batch-zi9hlczk1uwzljrevytef2qwqw41djv4wfnq)
# --------------------
# Job Name: batches/68ohlbuc7numz7ketcvkwizg4dh8povs8eoa
#   - Display Name: my-batch-job-with-image
#   - State: JOB_STATE_SUCCEEDED
#   - Create Time: 2025-09-10 22:46:36
#   - End Time: 2025-09-11 03:12:10
#   - Type: File-based (Output: files/batch-68ohlbuc7numz7ketcvkwizg4dh8povs8eoa)
# --------------------
# Job Name: batches/juotfcgfm48su8533h4mri00hhvn2vsr8zzz
#   - Display Name: file-upload-job-1
#   - State: JOB_STATE_SUCCEEDED
#   - Create Time: 2025-09-10 19:51:39
#   - End Time: 2025-09-11 03:19:59
#   - Type: File-based (Output: files/batch-juotfcgfm48su8533h4mri00hhvn2vsr8zzz)
# --------------------
# Job Name: batches/hlhhsbjwf7e2i2bx1jqjijoiw8qnpie2g4g2
#   - Display Name: file-upload-job-1
#   - State: BATCH_STATE_EXPIRED
#   - Create Time: 2025-09-03 12:19:31
# --------------------

# %%
import json

batch_job = client.batches.get(name="batches/vnb8p71ws0ug2mgdkb6vmo11xlxspy40okyd")

if batch_job.state.name == 'JOB_STATE_SUCCEEDED':
    # The output is in another file.
    result_file_name = batch_job.dest.file_name
    print(f"Results are in file: {result_file_name}")

    print("\nDownloading and parsing result file content...")
    file_content_bytes = client.files.download(file=result_file_name)
    file_content = file_content_bytes.decode('utf-8')

    # The result file is also a JSONL file. Parse and print each line.
    for line in file_content.splitlines():
      if line:
        parsed_response = json.loads(line)
        # Pretty-print the JSON for readability
        print(json.dumps(parsed_response, indent=2))
        print("-" * 20)
else:
    print(f"Job did not succeed. Final state: {batch_job.state.name}")
# Out:
# Results are in file: files/batch-vnb8p71ws0ug2mgdkb6vmo11xlxspy40okyd
#
# Downloading and parsing result file content...
# {
#   "generation_config": {
#     "response_schema": {
#       "title": "IndicatorExtraction",
#       "required": [
#         "indicator_id",
#         "value",
#         "unit",
#         "page_number",
#         "section"
#       ],
#       "type": "object",
#       "properties": {
#         "value": {
#           "type": "string",
#           "title": "Value"
#         },
#         "indicator_id": {
#           "title": "Indicator Id",
#           "type": "string"
#         },
#         "isDisclosed": {
#           "type": "integer",
#           "title": "Isdisclosed",
#           "default": 1
#         },
#         "page_number": {
#           "title": "Page Number",
#           "type": "string"
#         },
#         "section": {
#           "title": "Section",
#           "type": "string"
#         },
#         "unit": {
#           "type": "string",
#           "title": "Unit"
#         }
#       }
#     },
#     "thinking_config": {
#       "include_thoughts": true
#     },
#     "response_mime_type": "application/json"
#   },
#   "response": {
#     "responseId": "bQvDaKThMfS91MkP0qSogAY",
#     "usageMetadata": {
#       "thoughtsTokenCount": 2434,
#       "totalTokenCount": 39984,
#       "candidatesTokenCount": 170,
#       "promptTokensDetails": [
#         {
#           "modality": "TEXT",
#           "tokenCount": 228
#         },
#         {
#           "modality": "DOCUMENT",
#           "tokenCount": 37152
#         }
#       ],
#       "promptTokenCount": 37380
#     },
#     "candidates": [
#       {
#         "finishReason": "STOP",
#         "content": {
#           "role": "model",
#           "parts": [
#             {
#               "text": "```json\n{\n  \"is_disclosed\": 0,\n  \"indicator_id\": \"environmental_ex\",\n  \"value\": null,\n  \"unit\": null,\n  \"page_number\": null,\n  \"section\": \"The document provides information on money used for environmental purposes, such as $4.3 million in financial contribution from Business to Business (B2B) Offsets and sustainable aviation fuel (SAF) programs for 2023/24 (Page 41, 42, 43). It also mentions capital expenditure for fuel-efficient aircraft as part of its climate action plan (Page 75). However, the document does not explicitly state that any of these expenditures are 'EU Taxonomy aligned CapEx and OpEx'.\"\n}\n```"
#             }
#           ]
#         },
#         "citationMetadata": {
#           "citationSources": [
#             {
#               "uri": "https://www.listcorp.com/asx/qan/qantas-airways-limited/news/qantas-group-hy24-appendix-4d-and-interim-financial-report-2996874.html",
#               "startIndex": 2645,
#               "license": "",
#               "endIndex": 2934
#             },
#             {
#               "endIndex": 3218,
#               "license": "",
#               "startIndex": 2882,
#               "uri": "https://www.listcorp.com/asx/qan/qantas-airways-limited/news/qantas-group-fy22-appendix-4e-and-preliminary-final-report-2752657.html"
#             },
#             {
#               "endIndex": 3382,
#               "startIndex": 3105,
#               "uri": "https://www.listcorp.com/asx/qan/qantas-airways-limited/news/qantas-group-hy23-appendix-4d-and-interim-financial-report-2839506.html",
#               "license": ""
#             },
#             {
#               "startIndex": 3269,
#               "uri": "https://www.listcorp.com/asx/qan/qantas-airways-limited/news/qantas-group-hy24-appendix-4d-and-interim-financial-report-2996874.html",
#               "license": "",
#               "endIndex": 3629
#             },
#             {
#               "license": "",
#               "endIndex": 6248,
#               "uri": "https://www.listcorp.com/asx/qan/qantas-airways-limited/news/qantas-group-hy24-appendix-4d-and-interim-financial-report-2996874.html",
#               "startIndex": 5988
#             },
#             {
#               "startIndex": 10056,
#               "license": "",
#               "uri": "https://www.listcorp.com/asx/qan/qantas-airways-limited/news/qantas-group-fy22-appendix-4e-and-preliminary-final-report-2752657.html",
#               "endIndex": 10425
#             }
#           ]
#         },
#         "index": 0
#       }
#     ],
#     "modelVersion": "gemini-2.5-flash"
#   },
#   "key": "environmental_ex"
# }
# --------------------
# {
#   "generation_config": {
#     "response_mime_type": "application/json",
#     "response_schema": {
#       "properties": {
#         "page_number": {
#           "type": "string",
#           "title": "Page Number"
#         },
#         "section": {
#           "title": "Section",
#           "type": "string"
#         },
#         "isDisclosed": {
#           "default": 1,
#           "title": "Isdisclosed",
#           "type": "integer"
#         },
#         "value": {
#           "title": "Value",
#           "type": "string"
#         },
#         "indicator_id": {
#           "title": "Indicator Id",
#           "type": "string"
#         },
#         "unit": {
#           "title": "Unit",
#           "type": "string"
#         }
#       },
#       "required": [
#         "indicator_id",
#         "value",
#         "unit",
#         "page_number",
#         "section"
#       ],
#       "title": "IndicatorExtraction",
#       "type": "object"
#     },
#     "thinking_config": {
#       "include_thoughts": true
#     }
#   },
#   "response": {
#     "usageMetadata": {
#       "thoughtsTokenCount": 1444,
#       "totalTokenCount": 38914,
#       "candidatesTokenCount": 125,
#       "promptTokensDetails": [
#         {
#           "tokenCount": 193,
#           "modality": "TEXT"
#         },
#         {
#           "tokenCount": 37152,
#           "modality": "DOCUMENT"
#         }
#       ],
#       "promptTokenCount": 37345
#     },
#     "responseId": "aQvDaOO_JMis1MkPlZXvwQU",
#     "modelVersion": "gemini-2.5-flash",
#     "candidates": [
#       {
#         "index": 0,
#         "citationMetadata": {
#           "citationSources": [
#             {
#               "uri": "https://www.listcorp.com/asx/qan/qantas-airways-limited/news/qantas-group-hy24-appendix-4d-and-interim-financial-report-2996874.html",
#               "endIndex": 1776,
#               "startIndex": 1487,
#               "license": ""
#             },
#             {
#               "startIndex": 1724,
#               "uri": "https://www.listcorp.com/asx/qan/qantas-airways-limited/news/qantas-group-fy22-appendix-4e-and-preliminary-final-report-2752657.html",
#               "endIndex": 2060,
#               "license": ""
#             },
#             {
#               "uri": "https://www.listcorp.com/asx/qan/qantas-airways-limited/news/qantas-group-hy23-appendix-4d-and-interim-financial-report-2839506.html",
#               "license": "",
#               "startIndex": 1947,
#               "endIndex": 2224
#             },
#             {
#               "endIndex": 2698,
#               "startIndex": 2111,
#               "license": "",
#               "uri": ""
#             },
#             {
#               "license": "",
#               "endIndex": 2924,
#               "startIndex": 2595,
#               "uri": "https://www.listcorp.com/asx/qan/qantas-airways-limited/news/qantas-group-fy24-appendix-4e-and-preliminary-final-report-3076215.html"
#             },
#             {
#               "license": "",
#               "startIndex": 2886,
#               "endIndex": 3146,
#               "uri": "https://www.listcorp.com/asx/qan/qantas-airways-limited/news/qantas-group-hy24-appendix-4d-and-interim-financial-report-2996874.html"
#             },
#             {
#               "uri": "https://www.listcorp.com/asx/qan/qantas-airways-limited/news/qantas-group-fy22-appendix-4e-and-preliminary-final-report-2752657.html",
#               "license": "",
#               "endIndex": 5160,
#               "startIndex": 4725
#             }
#           ]
#         },
#         "finishReason": "STOP",
#         "content": {
#           "role": "model",
#           "parts": [
#             {
#               "text": "```json\n{\n  \"is_disclosed\": 1,\n  \"indicator_id\": \"lowCarbon_revenue\",\n  \"value\": \"4.3\",\n  \"unit\": \"M$\",\n  \"page_number\": \"41\",\n  \"section\": \"Financial contribution from Business to Business (B2B) Offsets and sustainable aviation fuel (SAF) programs \\n3.9 4.3 4.7 \\n4.3 \\nThe Group delivered $4.3 million in B2B Offsets and SAF programs.\"\n}\n```"
#             }
#           ]
#         }
#       }
#     ]
#   },
#   "key": "lowCarbon_revenue"
# }
# --------------------
# {
#   "key": "revenue",
#   "response": {
#     "candidates": [
#       {
#         "finishReason": "STOP",
#         "content": {
#           "parts": [
#             {
#               "text": "```json\n{\n  \"is_disclosed\": 1,\n  \"indicator_id\": \"revenue\",\n  \"value\": \"21,939\",\n  \"unit\": \"AUD millions\",\n  \"page_number\": \"68\",\n  \"section\": \"REVENUE AND OTHER INCOME\\nRevenue and other income\"\n}\n```"
#             }
#           ],
#           "role": "model"
#         },
#         "index": 0
#       }
#     ],
#     "modelVersion": "gemini-2.5-flash",
#     "usageMetadata": {
#       "candidatesTokenCount": 80,
#       "totalTokenCount": 38700,
#       "promptTokenCount": 37323,
#       "promptTokensDetails": [
#         {
#           "modality": "TEXT",
#           "tokenCount": 171
#         },
#         {
#           "tokenCount": 37152,
#           "modality": "DOCUMENT"
#         }
#       ],
#       "thoughtsTokenCount": 1297
#     },
#     "responseId": "agvDaM31MJaj1MkP1f-4qA4"
#   },
#   "generation_config": {
#     "response_mime_type": "application/json",
#     "thinking_config": {
#       "include_thoughts": true
#     },
#     "response_schema": {
#       "title": "IndicatorExtraction",
#       "type": "object",
#       "properties": {
#         "indicator_id": {
#           "title": "Indicator Id",
#           "type": "string"
#         },
#         "page_number": {
#           "type": "string",
#           "title": "Page Number"
#         },
#         "section": {
#           "type": "string",
#           "title": "Section"
#         },
#         "unit": {
#           "type": "string",
#           "title": "Unit"
#         },
#         "value": {
#           "title": "Value",
#           "type": "string"
#         },
#         "isDisclosed": {
#           "type": "integer",
#           "title": "Isdisclosed",
#           "default": 1
#         }
#       },
#       "required": [
#         "indicator_id",
#         "value",
#         "unit",
#         "page_number",
#         "section"
#       ]
#     }
#   }
# }
# --------------------
# {
#   "generation_config": {
#     "thinking_config": {
#       "include_thoughts": true
#     },
#     "response_mime_type": "application/json",
#     "response_schema": {
#       "type": "object",
#       "title": "IndicatorExtraction",
#       "required": [
#         "indicator_id",
#         "value",
#         "unit",
#         "page_number",
#         "section"
#       ],
#       "properties": {
#         "value": {
#           "type": "string",
#           "title": "Value"
#         },
#         "isDisclosed": {
#           "title": "Isdisclosed",
#           "type": "integer",
#           "default": 1
#         },
#         "unit": {
#           "title": "Unit",
#           "type": "string"
#         },
#         "page_number": {
#           "type": "string",
#           "title": "Page Number"
#         },
#         "indicator_id": {
#           "title": "Indicator Id",
#           "type": "string"
#         },
#         "section": {
#           "title": "Section",
#           "type": "string"
#         }
#       }
#     }
#   },
#   "key": "profit",
#   "response": {
#     "candidates": [
#       {
#         "finishReason": "STOP",
#         "content": {
#           "parts": [
#             {
#               "text": "```json\n{\n  \"is_disclosed\": 1,\n  \"indicator_id\": \"profit\",\n  \"value\": \"1,251\",\n  \"unit\": \"AUD millions\",\n  \"page_number\": \"66\",\n  \"section\": \"Statutory profit for the year 1,251\"\n}\n```"
#             }
#           ],
#           "role": "model"
#         },
#         "index": 0
#       }
#     ],
#     "responseId": "YgvDaJzuMN-i1MkP-denkA4",
#     "modelVersion": "gemini-2.5-flash",
#     "usageMetadata": {
#       "promptTokensDetails": [
#         {
#           "tokenCount": 184,
#           "modality": "TEXT"
#         },
#         {
#           "tokenCount": 37152,
#           "modality": "DOCUMENT"
#         }
#       ],
#       "totalTokenCount": 38186,
#       "promptTokenCount": 37336,
#       "candidatesTokenCount": 80,
#       "thoughtsTokenCount": 770
#     }
#   }
# }
# --------------------
# {
#   "key": "employees",
#   "response": {
#     "responseId": "aAvDaJ6LJNaQ1MkPpo6WwAU",
#     "usageMetadata": {
#       "promptTokensDetails": [
#         {
#           "modality": "TEXT",
#           "tokenCount": 220
#         },
#         {
#           "tokenCount": 37152,
#           "modality": "DOCUMENT"
#         }
#       ],
#       "candidatesTokenCount": 29,
#       "totalTokenCount": 38915,
#       "promptTokenCount": 37372,
#       "thoughtsTokenCount": 1514
#     },
#     "candidates": [
#       {
#         "finishReason": "STOP",
#         "content": {
#           "role": "model",
#           "parts": [
#             {
#               "text": "```json\n{\n  \"is_disclosed\": 0,\n  \"indicator_id\": \"employees\"\n}\n```"
#             }
#           ]
#         },
#         "index": 0,
#         "citationMetadata": {
#           "citationSources": [
#             {
#               "uri": "https://www.fool.com.au/2024/09/24/this-insider-just-spent-500k-on-qantas-shares/",
#               "license": "",
#               "startIndex": 916,
#               "endIndex": 1192
#             },
#             {
#               "uri": "https://www.sec.gov/Archives/edgar/data/1562767/000119312517083940/d278032df1.htm",
#               "endIndex": 5277,
#               "startIndex": 5036,
#               "license": ""
#             }
#           ]
#         }
#       }
#     ],
#     "modelVersion": "gemini-2.5-flash"
#   },
#   "generation_config": {
#     "response_mime_type": "application/json",
#     "response_schema": {
#       "title": "IndicatorExtraction",
#       "properties": {
#         "value": {
#           "title": "Value",
#           "type": "string"
#         },
#         "unit": {
#           "type": "string",
#           "title": "Unit"
#         },
#         "page_number": {
#           "title": "Page Number",
#           "type": "string"
#         },
#         "isDisclosed": {
#           "default": 1,
#           "title": "Isdisclosed",
#           "type": "integer"
#         },
#         "section": {
#           "type": "string",
#           "title": "Section"
#         },
#         "indicator_id": {
#           "title": "Indicator Id",
#           "type": "string"
#         }
#       },
#       "type": "object",
#       "required": [
#         "indicator_id",
#         "value",
#         "unit",
#         "page_number",
#         "section"
#       ]
#     },
#     "thinking_config": {
#       "include_thoughts": true
#     }
#   }
# }
# --------------------
