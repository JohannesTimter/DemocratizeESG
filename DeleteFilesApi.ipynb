# %%
from google import genai
client = genai.Client()

doNotDelete = ["files/uszqik7k9cle", "files/hpq49w5zi8pw", "files/94tym3ma5pfi", "files/ttz5ciobt6sg", "files/59tbhe3g01vw", "files/fruhezn9pz9t", "files/1a2yg4kso9lp", "files/igfkxd4jnx05", "files/p6vh13rdv6es", "files/cwd11lrgpfy3", "files/4uxp0gq5xcrn", "files/c0ncokti4d3g"]

print('My files:')
for f in client.files.list():
    print(' ', f.name)

    if f.name not in doNotDelete:
        client.files.delete(name=f.name)
        print('Deleted file:', f.name)
# Out:
# My files:
#   files/3tfa3es1n10g
# Deleted file: files/3tfa3es1n10g
#   files/rov6egg093ly
# Deleted file: files/rov6egg093ly
#   files/rbikd5ckjc9u
# Deleted file: files/rbikd5ckjc9u
#   files/omfspgcvbvk5
# Deleted file: files/omfspgcvbvk5
#   files/zrwhtuba4r4n
# Deleted file: files/zrwhtuba4r4n
#   files/mi6lck9rtkar
# Deleted file: files/mi6lck9rtkar
#   files/u8696q2sltz3
# Deleted file: files/u8696q2sltz3
#   files/b3s7gwv6f1sd
# Deleted file: files/b3s7gwv6f1sd
#   files/jgc3ljoguf5m
# Deleted file: files/jgc3ljoguf5m
#   files/k5qohrihue9l
# Deleted file: files/k5qohrihue9l
#   files/o6083ekqj0u5
# Deleted file: files/o6083ekqj0u5
#   files/hg75hz6j8tgr
# Deleted file: files/hg75hz6j8tgr
#   files/ftof7naf4tvu
# Deleted file: files/ftof7naf4tvu
#   files/nybto3qhhxyx
# Deleted file: files/nybto3qhhxyx
#   files/qt2nd93m0ega
# Deleted file: files/qt2nd93m0ega
#   files/74kb7j37lqmw
# Deleted file: files/74kb7j37lqmw
#   files/obdjfgvcwv8x
# Deleted file: files/obdjfgvcwv8x
#   files/i9e3mk82qa07
# Deleted file: files/i9e3mk82qa07
#   files/56wf6jnd5w8f
# Deleted file: files/56wf6jnd5w8f
#   files/ztsnwvf0cs80
# Deleted file: files/ztsnwvf0cs80
#   files/rn488lerk7cw
# Deleted file: files/rn488lerk7cw
#   files/p42gofzqva92
# Deleted file: files/p42gofzqva92
#   files/ig57wb8up3tr
# Deleted file: files/ig57wb8up3tr
#   files/ue8fx8qylwqn
# Deleted file: files/ue8fx8qylwqn
#   files/jpzt8b231bv9
# Deleted file: files/jpzt8b231bv9
#   files/q9pt01dhpb8i
# Deleted file: files/q9pt01dhpb8i
#   files/rltfdkeini5f
# Deleted file: files/rltfdkeini5f
#   files/2utmpei2mna8
# Deleted file: files/2utmpei2mna8
#   files/p92it5cimt7r
# Deleted file: files/p92it5cimt7r
#   files/ui56cvmx8nc5
# Deleted file: files/ui56cvmx8nc5
#   files/dqrgtpmo0b1e
# Deleted file: files/dqrgtpmo0b1e
#   files/8tcnf9funzee
# Deleted file: files/8tcnf9funzee
#   files/ysnsprd8v85m
# Deleted file: files/ysnsprd8v85m
#   files/tskw2z1w6ma0
# Deleted file: files/tskw2z1w6ma0
#   files/qtrym08ckppk
# Deleted file: files/qtrym08ckppk
#   files/9ivr92v5antw
# Deleted file: files/9ivr92v5antw
#   files/iwib8nqxri9t
# Deleted file: files/iwib8nqxri9t
#   files/570ppvbqf5jl
# Deleted file: files/570ppvbqf5jl
#   files/qncmbdyhtmnm
# Deleted file: files/qncmbdyhtmnm
#   files/ifbyqr98a9i7
# Deleted file: files/ifbyqr98a9i7
#   files/zda9r1a3lg5d
# Deleted file: files/zda9r1a3lg5d
#   files/3xag3uhdem28
# Deleted file: files/3xag3uhdem28
#   files/yu19d3s9zikt
# Deleted file: files/yu19d3s9zikt
#   files/880pbrcbzyu3
# Deleted file: files/880pbrcbzyu3
#   files/m5kmtb8vyep2
# Deleted file: files/m5kmtb8vyep2
#   files/gzn6xam579fu
# Deleted file: files/gzn6xam579fu
#   files/m6zv6vof6sl4
# Deleted file: files/m6zv6vof6sl4
#   files/hvn7dj89vnp6
# Deleted file: files/hvn7dj89vnp6
#   files/mopysvsl20yt
# Deleted file: files/mopysvsl20yt
#   files/lql4odb1yaa9
# Deleted file: files/lql4odb1yaa9
#   files/bg5uizmyb5ta
# Deleted file: files/bg5uizmyb5ta
#   files/eex5sypza3yq
# Deleted file: files/eex5sypza3yq
#   files/944ijrb6aiwv
# Deleted file: files/944ijrb6aiwv
#   files/hexz6ogu0dkd
# Deleted file: files/hexz6ogu0dkd
#   files/r37d72jbcyrt
# Deleted file: files/r37d72jbcyrt
#   files/p6ds773no837
# Deleted file: files/p6ds773no837
#   files/rp5knkhijth0
# Deleted file: files/rp5knkhijth0
#   files/bvcxisy2boeh
# Deleted file: files/bvcxisy2boeh
#   files/fzs4amky1l49
# Deleted file: files/fzs4amky1l49
#   files/a8kyelihf618
# Deleted file: files/a8kyelihf618
#   files/32j4dq1cqn9n
# Deleted file: files/32j4dq1cqn9n
#   files/0v9jvthhxdjz
# Deleted file: files/0v9jvthhxdjz
#   files/wixsin2y9gbr
# Deleted file: files/wixsin2y9gbr
#   files/pabgujz7u831
# Deleted file: files/pabgujz7u831
#   files/vh6pghzjkpt0
# Deleted file: files/vh6pghzjkpt0
#   files/apjd12xvous1
# Deleted file: files/apjd12xvous1
#   files/i1zfjh0iq0wf
# Deleted file: files/i1zfjh0iq0wf
#   files/9nvau1dz3g32
# Deleted file: files/9nvau1dz3g32
#   files/12o073lcnqe9
# Deleted file: files/12o073lcnqe9
#   files/nvhlna4iy2vs
# Deleted file: files/nvhlna4iy2vs
#   files/w9rboewtuqtf
# Deleted file: files/w9rboewtuqtf
#   files/o5i7q6zm6sek
# Deleted file: files/o5i7q6zm6sek
#   files/nt3wei9f5vmt
# Deleted file: files/nt3wei9f5vmt
#   files/jgh6e7xxbbk6
# Deleted file: files/jgh6e7xxbbk6
#   files/uo6ywljkn84g
# Deleted file: files/uo6ywljkn84g
#   files/oisdlp6uoix3
# Deleted file: files/oisdlp6uoix3
#   files/rehlysbpli2w
# Deleted file: files/rehlysbpli2w
#   files/eoriqthcyucc
# Deleted file: files/eoriqthcyucc
#   files/jn4pw061kkf2
# Deleted file: files/jn4pw061kkf2
#   files/fdy7kscoth8s
# Deleted file: files/fdy7kscoth8s
#   files/wav4c63d2xup
# Deleted file: files/wav4c63d2xup
#   files/g752dz71qcqu
# Deleted file: files/g752dz71qcqu
#   files/ooowtfqcr06m
# Deleted file: files/ooowtfqcr06m
#   files/vgq6xv6zvz7k
# Deleted file: files/vgq6xv6zvz7k
#   files/y3w1k0ogqppi
# Deleted file: files/y3w1k0ogqppi
#   files/2z0sywjcby0n
# Deleted file: files/2z0sywjcby0n
#   files/3r71dcs50yek
# Deleted file: files/3r71dcs50yek
#   files/ot5mjrl82a7k
# Deleted file: files/ot5mjrl82a7k
#   files/u8ikb4ftgw2x
# Deleted file: files/u8ikb4ftgw2x
#   files/745udfsqqtdk
# Deleted file: files/745udfsqqtdk
#   files/d9z4w0jwrknw
# Deleted file: files/d9z4w0jwrknw
#   files/ru4n3xqupe6r
# Deleted file: files/ru4n3xqupe6r
#   files/iijdomemzmo3
# Deleted file: files/iijdomemzmo3
#   files/yeikaz2x5gtr
# Deleted file: files/yeikaz2x5gtr
#   files/46116lopp214
# Deleted file: files/46116lopp214
#   files/8j8rkwxr1xqy
# Deleted file: files/8j8rkwxr1xqy
#   files/6h9vdan2zq5b
# Deleted file: files/6h9vdan2zq5b
#   files/77ewxd9n93c1
# Deleted file: files/77ewxd9n93c1
#   files/4nn4ry6klm3e
# Deleted file: files/4nn4ry6klm3e
#   files/ybgga82z0ffl
# Deleted file: files/ybgga82z0ffl
#   files/7ft5rkhwx26e
# Deleted file: files/7ft5rkhwx26e
#   files/wfsajabk16u6
# Deleted file: files/wfsajabk16u6
#   files/1cpbm22qopfb
# Deleted file: files/1cpbm22qopfb
#   files/9rcn8olyytru
# Deleted file: files/9rcn8olyytru
#   files/05vrsapchh5h
# Deleted file: files/05vrsapchh5h
#   files/bvc8gvtri7p0
# Deleted file: files/bvc8gvtri7p0
#   files/8ckk2olzwi11
# Deleted file: files/8ckk2olzwi11
#   files/99gdsm9uj0m1
# Deleted file: files/99gdsm9uj0m1
#   files/t3i8b1m9793l
# Deleted file: files/t3i8b1m9793l
#   files/q7f5j5vgtv7r
# Deleted file: files/q7f5j5vgtv7r
#   files/thg7mv11ckdw
# Deleted file: files/thg7mv11ckdw
#   files/g1jerafzbczx
# Deleted file: files/g1jerafzbczx
#   files/9px8znw7xsz2
# Deleted file: files/9px8znw7xsz2
#   files/974214l80t5r
# Deleted file: files/974214l80t5r
#   files/l304vaynahku
# Deleted file: files/l304vaynahku
#   files/amfkqrtplhoz
# Deleted file: files/amfkqrtplhoz
#   files/aqnk4mpmb8e8
# Deleted file: files/aqnk4mpmb8e8
#   files/jcfq78krrlkt
# Deleted file: files/jcfq78krrlkt
#   files/481arg2s26c8
# Deleted file: files/481arg2s26c8
#   files/pthhpenfeu8w
# Deleted file: files/pthhpenfeu8w
#   files/f4h7amk2vuei
# Deleted file: files/f4h7amk2vuei
#   files/izd11nr6rp46
# Deleted file: files/izd11nr6rp46
#   files/zrvazpad7nwh
# Deleted file: files/zrvazpad7nwh
#   files/zi7dd735oxq6
# Deleted file: files/zi7dd735oxq6
#   files/pxdte7h3fi1i
# Deleted file: files/pxdte7h3fi1i
#   files/rljm8lyym5ag
# Deleted file: files/rljm8lyym5ag
#   files/p6chp81oftg1
# Deleted file: files/p6chp81oftg1
#   files/9qaukyd7f2nj
# Deleted file: files/9qaukyd7f2nj
#   files/emwb4uinahn7
# Deleted file: files/emwb4uinahn7
#   files/p7ik5d3ehtg9
# Deleted file: files/p7ik5d3ehtg9
#   files/pf9pinuhsmnk
# Deleted file: files/pf9pinuhsmnk
#   files/bl9g4fbll1i7
# Deleted file: files/bl9g4fbll1i7
#   files/wu9g48sbmlii
# Deleted file: files/wu9g48sbmlii
#   files/8n7enjs31228
# Deleted file: files/8n7enjs31228
#   files/qgq74e4lyuhz
# Deleted file: files/qgq74e4lyuhz
#   files/liwviux4o1xk
# Deleted file: files/liwviux4o1xk
#   files/sz6xkz202pf5
# Deleted file: files/sz6xkz202pf5
#   files/mi1jmdilrmrc
# Deleted file: files/mi1jmdilrmrc
#   files/tclpmmh7rd9j
# Deleted file: files/tclpmmh7rd9j
#   files/1gkufc3rm14m
# Deleted file: files/1gkufc3rm14m
#   files/s3ndybm3w2ka
# Deleted file: files/s3ndybm3w2ka
#   files/x706h6hfjmla
# Deleted file: files/x706h6hfjmla
#   files/9z6pcdd4ik2n
# Deleted file: files/9z6pcdd4ik2n
#   files/ri6nb04u2e2d
# Deleted file: files/ri6nb04u2e2d
#   files/u6zstk34x4tf
# Deleted file: files/u6zstk34x4tf
#   files/y88aolhu2imq
# Deleted file: files/y88aolhu2imq
#   files/3joto9axiamv
# Deleted file: files/3joto9axiamv
#   files/io2khz6gz32t
# Deleted file: files/io2khz6gz32t
#   files/a1phoowffden
# Deleted file: files/a1phoowffden
#   files/40yslrqvli77
# Deleted file: files/40yslrqvli77
#   files/ogckl408c6yu
# Deleted file: files/ogckl408c6yu
#   files/u13ayl9b3f60
# Deleted file: files/u13ayl9b3f60
#   files/m00h6348s3ih
# Deleted file: files/m00h6348s3ih
#   files/sfya95p37e2b
# Deleted file: files/sfya95p37e2b
#   files/0ijnolhiz4aa
# Deleted file: files/0ijnolhiz4aa
#   files/20rlhy5ibkc5
# Deleted file: files/20rlhy5ibkc5
#   files/9hgnkwx6zm62
# Deleted file: files/9hgnkwx6zm62
#   files/x2qzcacggw99
# Deleted file: files/x2qzcacggw99
#   files/8ihue1jetsy6
# Deleted file: files/8ihue1jetsy6
#   files/s1xjozvhu4zt
# Deleted file: files/s1xjozvhu4zt
#   files/5ekuyhfbf488
# Deleted file: files/5ekuyhfbf488
#   files/txu5e5iuoas7
# Deleted file: files/txu5e5iuoas7
#   files/ygs8ak5iplbc
# Deleted file: files/ygs8ak5iplbc
#   files/oe3copz8ye9w
# Deleted file: files/oe3copz8ye9w
#   files/mp6qh1j88jgm
# Deleted file: files/mp6qh1j88jgm
#   files/cl26hmp28f5v
# Deleted file: files/cl26hmp28f5v
#   files/fwmfgsnq4qk6
# Deleted file: files/fwmfgsnq4qk6
#   files/hlrj4rtn18h1
# Deleted file: files/hlrj4rtn18h1
#   files/30w44o961795
# Deleted file: files/30w44o961795
#   files/7dayskql1tue
# Deleted file: files/7dayskql1tue
#   files/bpkrwzjky4hg
# Deleted file: files/bpkrwzjky4hg
#   files/flk40x4wzpif
# Deleted file: files/flk40x4wzpif
#   files/gzk6v7es60fe
# Deleted file: files/gzk6v7es60fe
#   files/fzsx7n0gfae2
# Deleted file: files/fzsx7n0gfae2
#   files/f5jhrnjoko22
# Deleted file: files/f5jhrnjoko22
#   files/ga4lbfivqo4z
# Deleted file: files/ga4lbfivqo4z
#   files/sen0695fmhha
# Deleted file: files/sen0695fmhha
#   files/cnun26krox6h
# Deleted file: files/cnun26krox6h
#   files/93c0nbuxgrl7
# Deleted file: files/93c0nbuxgrl7
#   files/1j9gh2uvucol
# Deleted file: files/1j9gh2uvucol
#   files/w7z1w9h5ejo8
# Deleted file: files/w7z1w9h5ejo8
#   files/0rkr8qfz81j7
# Deleted file: files/0rkr8qfz81j7
#   files/zfnevkvdl3az
# Deleted file: files/zfnevkvdl3az
#   files/1mm0b4usvwhv
# Deleted file: files/1mm0b4usvwhv
#   files/y6aobd9ckd4a
# Deleted file: files/y6aobd9ckd4a
#   files/9txbf8g6zbni
# Deleted file: files/9txbf8g6zbni
#   files/17idnrqivb87
# Deleted file: files/17idnrqivb87
#   files/fth9xcs3f42c
# Deleted file: files/fth9xcs3f42c
#   files/zaaawqty5o0f
# Deleted file: files/zaaawqty5o0f
#   files/4bvu425u1llx
# Deleted file: files/4bvu425u1llx
#   files/u4y99cbkcbpq
# Deleted file: files/u4y99cbkcbpq
#   files/1po6itt0nwhe
# Deleted file: files/1po6itt0nwhe
#   files/2v672apdtcjk
# Deleted file: files/2v672apdtcjk
#   files/owyv8b68wguc
# Deleted file: files/owyv8b68wguc
#   files/1ef37orh95ff
# Deleted file: files/1ef37orh95ff
#   files/nyqepoj55xof
# Deleted file: files/nyqepoj55xof
#   files/gofmgh1j5fin
# Deleted file: files/gofmgh1j5fin
#   files/7ppyx3fjn3nz
# Deleted file: files/7ppyx3fjn3nz
#   files/3ymua4e11wov
# Deleted file: files/3ymua4e11wov
#   files/argsgxi4ja1v
# Deleted file: files/argsgxi4ja1v
#   files/2o79mz4y2ik9
# Deleted file: files/2o79mz4y2ik9
#   files/wcb842dexz0m
# Deleted file: files/wcb842dexz0m
#   files/75h1nu892mcr
# Deleted file: files/75h1nu892mcr
#   files/vbxfey7gfpz7
# Deleted file: files/vbxfey7gfpz7
#   files/pwbatzlsufuf
# Deleted file: files/pwbatzlsufuf
#   files/z6bedyo0micb
# Deleted file: files/z6bedyo0micb
#   files/quit2m9mfuht
# Deleted file: files/quit2m9mfuht
#   files/jt57q03dxwvh
# Deleted file: files/jt57q03dxwvh
#   files/eg1solwia9zq
# Deleted file: files/eg1solwia9zq
#   files/xc1tzv7gd96w
# Deleted file: files/xc1tzv7gd96w
#   files/vo0ec0400vee
# Deleted file: files/vo0ec0400vee
#   files/d0v9mmoylazj
# Deleted file: files/d0v9mmoylazj
#   files/clf3croajoi3
# Deleted file: files/clf3croajoi3
#   files/pz7hi4znlmyw
# Deleted file: files/pz7hi4znlmyw
#   files/n8dtqe2hjx9u
# Deleted file: files/n8dtqe2hjx9u
#   files/bqujuigis0dx
# Deleted file: files/bqujuigis0dx
#   files/m6wdjixov163
# Deleted file: files/m6wdjixov163
#   files/0lk6pcey3hsh
# Deleted file: files/0lk6pcey3hsh
#   files/pb5n55qppo1z
# Deleted file: files/pb5n55qppo1z
#   files/m00qzqkjvm2k
# Deleted file: files/m00qzqkjvm2k
#   files/kh8r97zzkast
# Deleted file: files/kh8r97zzkast
#   files/mcq4n2mvclaw
# Deleted file: files/mcq4n2mvclaw
#   files/smdr7w6rijeu
# Deleted file: files/smdr7w6rijeu
#   files/tljqeag7va2m
# Deleted file: files/tljqeag7va2m
#   files/lu24d85nlwpj
# Deleted file: files/lu24d85nlwpj
#   files/xd1nwkcyde68
# Deleted file: files/xd1nwkcyde68
#   files/uddlz7lovww8
# Deleted file: files/uddlz7lovww8
#   files/jlmy50y3xn6h
# Deleted file: files/jlmy50y3xn6h
#   files/4u8s19n58tou
# Deleted file: files/4u8s19n58tou
#   files/pju9kuu4lozm
# Deleted file: files/pju9kuu4lozm
#   files/72h1a4cf0spx
# Deleted file: files/72h1a4cf0spx
#   files/t5mxhkwa5bxc
# Deleted file: files/t5mxhkwa5bxc
#   files/av02sncxvoya
# Deleted file: files/av02sncxvoya
#   files/uyeplge891ni
# Deleted file: files/uyeplge891ni
#   files/zny0ihjj4ox9
# Deleted file: files/zny0ihjj4ox9
#   files/xrh7qrlkgpre
# Deleted file: files/xrh7qrlkgpre
#   files/gwfccefmlnaz
# Deleted file: files/gwfccefmlnaz
#   files/4bxea225fv8b
# Deleted file: files/4bxea225fv8b
#   files/0cswuahdrzu3
# Deleted file: files/0cswuahdrzu3
#   files/na2g9f0ta6k7
# Deleted file: files/na2g9f0ta6k7
#   files/a4bdfh1vcnjq
# Deleted file: files/a4bdfh1vcnjq
#   files/ho2xopng25j7
# Deleted file: files/ho2xopng25j7
#   files/mi5gkkkrmhjh
# Deleted file: files/mi5gkkkrmhjh
#   files/9d0a326320tf
# Deleted file: files/9d0a326320tf
#   files/krnzxo72kwqc
# Deleted file: files/krnzxo72kwqc
#   files/28azzjvl9smo
# Deleted file: files/28azzjvl9smo
#   files/l3d9ucbljo4s
# Deleted file: files/l3d9ucbljo4s
#   files/el8e8lmhilbx
# Deleted file: files/el8e8lmhilbx
#   files/chmrvl9inotx
# Deleted file: files/chmrvl9inotx
#   files/35terumv6hhh
# Deleted file: files/35terumv6hhh
#   files/2un7k64dbnw3
# Deleted file: files/2un7k64dbnw3
#   files/l5u3cjghpmqq
# Deleted file: files/l5u3cjghpmqq
#   files/4rn44i0z7psl
# Deleted file: files/4rn44i0z7psl
#   files/lba850mit3zs
# Deleted file: files/lba850mit3zs
#   files/7hapjyjzsl3o
# Deleted file: files/7hapjyjzsl3o
#   files/exr4ihgad24h
# Deleted file: files/exr4ihgad24h
#   files/8fvuyeit2cb1
# Deleted file: files/8fvuyeit2cb1
#   files/zu8dssr7xgk1
# Deleted file: files/zu8dssr7xgk1
#   files/yadt5klcnd0y
# Deleted file: files/yadt5klcnd0y
#   files/9xk7s7luwd44
# Deleted file: files/9xk7s7luwd44
#   files/avh6ydtwqwj0
# Deleted file: files/avh6ydtwqwj0
#   files/bc5nmg2ib3c4
# Deleted file: files/bc5nmg2ib3c4
#   files/9s37hote6omc
# Deleted file: files/9s37hote6omc
#   files/sk168ry8oiro
# Deleted file: files/sk168ry8oiro
#   files/2hxnwj8mu98r
# Deleted file: files/2hxnwj8mu98r
#   files/tu2ok0zy574g
# Deleted file: files/tu2ok0zy574g
#   files/ztcl02l55nwx
# Deleted file: files/ztcl02l55nwx
#   files/mur12nl8uu73
# Deleted file: files/mur12nl8uu73
#   files/0le7knr2ux85
# Deleted file: files/0le7knr2ux85
#   files/3kgh8sn1oc2r
# Deleted file: files/3kgh8sn1oc2r
#   files/7ovdeehapojs
# Deleted file: files/7ovdeehapojs
#   files/c7qifskj1x46
# Deleted file: files/c7qifskj1x46
#   files/r40zry8ab03m
# Deleted file: files/r40zry8ab03m
#   files/f7dw2ua6o03z
# Deleted file: files/f7dw2ua6o03z
#   files/i8beq2m72at2
# Deleted file: files/i8beq2m72at2
#   files/h1ag0jq2sfg1
# Deleted file: files/h1ag0jq2sfg1
#   files/1lyralaa0cie
# Deleted file: files/1lyralaa0cie
#   files/kxb8qybykomn
# Deleted file: files/kxb8qybykomn
#   files/o76wvt9nqc05
# Deleted file: files/o76wvt9nqc05
#   files/nu6dvhq4jlqi
# Deleted file: files/nu6dvhq4jlqi
#   files/wyio8mtync6s
# Deleted file: files/wyio8mtync6s
#   files/c2nfqerud4sa
# Deleted file: files/c2nfqerud4sa
#   files/u126gr2hn67g
# Deleted file: files/u126gr2hn67g
#   files/51s8a7gteidw
# Deleted file: files/51s8a7gteidw
#   files/6z5xgnmijm1s
# Deleted file: files/6z5xgnmijm1s
#   files/d4ytd1cwhpgg
# Deleted file: files/d4ytd1cwhpgg
#   files/zg9xmduuva7u
# Deleted file: files/zg9xmduuva7u
#   files/blitj13smeoy
# Deleted file: files/blitj13smeoy
#   files/mjlvpb43ysl6
# Deleted file: files/mjlvpb43ysl6
#   files/nrwuyqidnb9d
# Deleted file: files/nrwuyqidnb9d
#   files/cser9w3eln3n
# Deleted file: files/cser9w3eln3n
#   files/9juatgp13s3w
# Deleted file: files/9juatgp13s3w
#   files/ker81u6bhu4x
# Deleted file: files/ker81u6bhu4x
#   files/qeu2p1p335g4
# Deleted file: files/qeu2p1p335g4
#   files/jbsm137kbk7z
# Deleted file: files/jbsm137kbk7z
#   files/gcsmkmrerjdl
# Deleted file: files/gcsmkmrerjdl
#   files/5wlt3mvgt2i3
# Deleted file: files/5wlt3mvgt2i3
#   files/laoqeq1idpv4
# Deleted file: files/laoqeq1idpv4
#   files/iwm5860he2e0
# Deleted file: files/iwm5860he2e0
#   files/k9vhvhxl4rt2
# Deleted file: files/k9vhvhxl4rt2
#   files/va77pch79sex
# Deleted file: files/va77pch79sex
#   files/3vaghxn3j07w
# Deleted file: files/3vaghxn3j07w
#   files/e459j8e13vc3
# Deleted file: files/e459j8e13vc3
#   files/st721nxj6tgj
# Deleted file: files/st721nxj6tgj
#   files/65qfx0sj4tme
# Deleted file: files/65qfx0sj4tme
#   files/20cio564faw5
# Deleted file: files/20cio564faw5
#   files/m1aj0u5wa20t
# Deleted file: files/m1aj0u5wa20t
#   files/glup63b11vog
# Deleted file: files/glup63b11vog
#   files/q0b1fwyieidt
# Deleted file: files/q0b1fwyieidt
#   files/vpkmgnwxmxxc
# Deleted file: files/vpkmgnwxmxxc
#   files/nm0cna5tkmec
# Deleted file: files/nm0cna5tkmec
#   files/3pty29j3uizg
# Deleted file: files/3pty29j3uizg
#   files/1h39nyos808o
# Deleted file: files/1h39nyos808o
#   files/wejblwj0azdk
# Deleted file: files/wejblwj0azdk
#   files/4915htco5u74
# Deleted file: files/4915htco5u74
#   files/95vff2l315ve
# Deleted file: files/95vff2l315ve
#   files/yw754nc0zh5l
# Deleted file: files/yw754nc0zh5l
#   files/csjcjmr1x6py
# Deleted file: files/csjcjmr1x6py
#   files/gifk1iho70z6
# Deleted file: files/gifk1iho70z6
#   files/zws5e8oz93da
# Deleted file: files/zws5e8oz93da
#   files/aocnzyu2omi3
# Deleted file: files/aocnzyu2omi3
#   files/wi8smfzolx96
# Deleted file: files/wi8smfzolx96
#   files/1r0h8ljuynj7
# Deleted file: files/1r0h8ljuynj7
#   files/c9qeqmtyvj0q
# Deleted file: files/c9qeqmtyvj0q
#   files/wgdd1oa38gwk
# Deleted file: files/wgdd1oa38gwk
#   files/fzfjgrz40t68
# Deleted file: files/fzfjgrz40t68
#   files/arxtzbvl4wkh
# Deleted file: files/arxtzbvl4wkh
#   files/f6zlso1rwkoz
# Deleted file: files/f6zlso1rwkoz
#   files/lyy0x6rftn3d
# Deleted file: files/lyy0x6rftn3d
#   files/wgh7zfd0ce22
# Deleted file: files/wgh7zfd0ce22
#   files/q7097ifh0jhi
# Deleted file: files/q7097ifh0jhi
#   files/gbf2pdwim9md
# Deleted file: files/gbf2pdwim9md
#   files/wlkub4rym1c4
# Deleted file: files/wlkub4rym1c4

# %%
import sys

print(f"Original recursion limit: {sys.getrecursionlimit()}")

sys.setrecursionlimit(6000)
# Out:
# Original recursion limit: 3000
